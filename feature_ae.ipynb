# %% [markdown]
# <a href="https://colab.research.google.com/github/Kristin33/Composer-Clustering/blob/master/feature_ae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
import librosa, librosa.display
import matplotlib.pyplot as plt 

from scipy import stats

import numpy as np 
import pandas as pd 

from PIL import Image
from time import time

from sklearn.cluster import SpectralClustering, MeanShift, KMeans, AgglomerativeClustering

# %% [markdown]
# # Data directories and experiment

# %%
# directory variables 

# 之前我试csv的时候
alkan_csv = "alkan_all.csv"
bach_csv = "bach_all.csv"
beethoven_csv = "beethoven_all.csv"
brahms_csv = "brahms_all.csv"
buxtehude_csv = "buxtehude_all.csv"
byrd_csv = "byrd_all.csv"
chopin_csv = "chopin_all.csv"
dandrieu_csv = "dandrieu_all.csv"
dvorak_csv = "dvorak_all.csv"
debussy_csv = "debussy_all.csv"
faure_csv = "faure_all.csv"
handel_csv = "handel_all.csv"
haydn_csv = "haydn_all.csv"
mozart_csv = "mozart_all.csv"
scarlatti_csv = "scarlatti_all.csv"
schubert_csv = "schubert_all.csv"
schumann_csv = "schumann_all.csv"
scriabin_csv = "scriabin_all.csv"
shostakovich_csv = "shostakovich_all.csv"
soler_csv = "soler_all.csv"

train_csv_comps = [alkan_csv, bach_csv,
                   brahms_csv, buxtehude_csv, byrd_csv, 
                   chopin_csv, dandrieu_csv, dvorak_csv, debussy_csv,
                   faure_csv, handel_csv, haydn_csv,
                   mozart_csv, scarlatti_csv, schubert_csv,
                  schumann_csv, scriabin_csv, shostakovich_csv, soler_csv]
test_csv_comps = [alkan_csv, bach_csv, beethoven_csv,
                   brahms_csv]
                  # , buxtehude_csv, byrd_csv, 
                  #  chopin_csv, dandrieu_csv, dvorak_csv,
                  #  faure_csv, handel_csv, haydn_csv,
                  #  mozart_csv, scarlatti_csv, schubert_csv,
                  # schumann_csv, scriabin_csv, shostakovich_csv, soler_csv]

# %%
"""
===========================================================
Get the piano roll encoding of midi files 
===========================================================

Attempt of using autoencoders to encode the pianoroll representation
into a lower dimension latent representation. 

currently, the input of the piano roll is of dimension 128000

"""

# dimension: 128 * 1000
# 128: midi 有128个note，C4 = 60
# 1000，对于时间上的sampling
# matrix 里面，应该是0-127之间的一个数，表示这个音的音量
def get_piano_roll_matrix(midi_data, start_pitch, end_pitch, fs=50, draw=False):
    # roll = midi_data.get_piano_roll(fs)[start_pitch:end_pitch]
    matrix = midi_data.get_piano_roll(fs)[:, :1000]
    # print(matrix[:, 30:40])
    # print(matrix.shape)

    if draw: 
      print("drawing...")
      librosa.display.specshow(matrix,
            hop_length=1, sr=fs, x_axis='time', y_axis='cqt_note',
            fmin=pretty_midi.note_number_to_hz(start_pitch))
    return np.array(matrix)

# input: an array of test composers, like [scirabin_dir, bach_dir]
def extract_rolls(comps, verbose=False):
    
    data_dir = "New_Data_Selection/"

    for idx, comp in enumerate(comps):
      print(comp)
      for filename in os.listdir(data_dir + comp):
          
          if ".mid" in filename or ".MID" in filename:
              if verbose:
                print(filename)
              try:
                midi_data = pretty_midi.PrettyMIDI(data_dir + comp + filename)
                l = midi_data.get_end_time()
                # scale the sampling frequency by the length of data, so the picture is 
                # of the same size 128 * 1000
                fs = 50 * (1000/(l * 50 - 1))
                roll = get_piano_roll_matrix(midi_data,36,108,fs=fs,draw=False)

                # plt.gray()
                if not os.path.exists('pianoroll/{}'.format(comp)):
                  os.mkdir('pianoroll/{}'.format(comp))
                plt.imsave("pianoroll/{}/{}.png".format(comp, filename),
                          roll)
                print(filename + "saved")
                # print(np.sum(roll, axis=0))
              except Exception as e: 
                print(e)
                pass

    return 

# read all the file in the composer directory, and return 
# np array of (n, 128, 1000)
def read_comp(comp):
  path = "pianoroll/" + comp
  data = np.empty((0, 128, 1000))
  for filename in os.listdir(path):
    img = np.asarray(Image.open("{}/{}".format(path, filename)).convert("L"))
    np.append(data, img, axis=0)
    print(img.shape)
  return data


def get_train_data(train_comps):
    
    data_dir = "drive/My Drive/10701/pianoroll/"

    composer_data = np.empty((0, 776))
    composer_label = np.empty((0,))


    for comp in train_comps:
        data = read_comp(comp)

        composer_data = np.append(composer_data, data, axis=0)
        composer_label = np.append(composer_label, np.zeros((data.shape[0],)), axis=0)

    data = composer_data
    labels = composer_label

    return data, labels

# %% [markdown]
# # Fetch data: old csv files

# %%
def get_csv_train_data(train_csv_comps):
    
    data_dir = "drive/My Drive/10701/composer_csv/"

    composer_data = np.empty((0, 776))
    composer_label = np.empty((0,))

    for filename in train_csv_comps:
        data = np.genfromtxt(data_dir + filename, delimiter=',', 
                             usecols=np.arange(1,777), encoding="latin1")
        # get rid of the top row with feature names
        data = data[1:,:]

        composer_data = np.append(composer_data, data, axis=0)
        composer_label = np.append(composer_label, np.zeros((data.shape[0],)), axis=0)

    data = composer_data
    # standarize the data
    data = stats.zscore(data)
    data = np.nan_to_num(data)
    labels = composer_label

    return data, labels

def get_csv_test_data(test_csv_comps):
    
    data_dir = "drive/My Drive/10701/composer_csv/"

    composer_data = np.empty((0, 776))
    composer_label = np.empty((0,))
    

    for idx, filename in enumerate(test_csv_comps):
        print(filename)
        data = np.genfromtxt(data_dir + filename, delimiter=',', 
                             usecols=np.arange(1,777), encoding='latin1')
        # get rid of the top row with feature names
        data = data[1:,:]
        # standarize the data
        data = stats.zscore(data)
        data = np.nan_to_num(data)

        composer_data = np.append(composer_data, data, axis=0)
        composer_label = np.append(composer_label, np.ones((data.shape[0],)) * idx, axis=0)

    data = composer_data
    labels = composer_label

    return data, labels


# d, l = get_csv_train_data([dandrieu_csv])

# %% [markdown]
# # Fetch training data for autoencoders

# %%
"""
===========================================================
Auto encoders
===========================================================

Attempt of using autoencoders to encode the pianoroll representation
into a lower dimension latent representation. 

currently, the input of the piano roll is of dimension 1280000


"""

import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %tensorflow_version 1.x
import tensorflow as tf
# from __future__ import print_function
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.datasets import mnist
from tensorflow.keras.regularizers import l1
from tensorflow.keras.optimizers import Adam
from keras import regularizers
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
(x_train, y_train) = get_csv_train_data(train_csv_comps)

# x_train = x_train.astype('float32') / 255.0

# x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))


print(x_train.shape)
# Out:
# (4202, 776)

# %% [markdown]
# # Construct Model and Train

# %%
# 返回一个autoencoder的model
def get_ae(input_size):
  # if using piano roll, input_size = 1280000, if jSymbolic feature, size is 776 
  hidden_size = 128
  code_size = 32

  input_img = Input(shape=(input_size,))
  hidden_1 = Dense(hidden_size, activation='relu')(input_img)
  code = Dense(code_size, activation='relu')(hidden_1)
  hidden_2 = Dense(hidden_size, activation='relu')(code)
  output_img = Dense(input_size, activation='sigmoid')(hidden_2)


  # input_img = Input(shape=(input_size,))
  # encoded = Dense(128, activation='relu', activity_regularizer=regularizers.l1(10e-5))(input_img)
  # encoded = Dense(64, activation='relu', activity_regularizer=regularizers.l1(10e-5))(encoded)
  # encoded = Dense(32, activation='relu', activity_regularizer=regularizers.l1(10e-5))(encoded)
  # code = Dense(8, activation='relu', activity_regularizer=regularizers.l1(10e-5))(encoded)
  # decoded = Dense(32, activation='relu')(code)
  # decoded = Dense(64, activation='relu')(decoded)
  # decoded = Dense(128, activation='relu')(decoded)
  # output_img = Dense(input_size, activation='sigmoid')(decoded)


  autoencoder = Model(input_img, output_img)
  autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
  autoencoder_half = Model(input_img, code)

  return autoencoder, autoencoder_half

# %%
# train autoencoder 


# if using piano roll, input_size = 1280000, if jSymbolic feature, size is 776 
input_size = 776
# autoencoder, autoencoder_half = get_ae(input_size)
# autoencoder_train = autoencoder.fit(x_train, x_train, epochs=10)


# # 可以改（成get_ae）！但是记得要把x_train改成正确的dimension，而且x_test也要同时改了
# autoencoder = get_conv_ae(input_size)
# # x_train = np.reshape(x_train, (len(x_train), 1, 128, 10000))
# a = np.reshape(x_train, (len(x_train), 128, 10000, 1))
# x_train_new = a[:, 8:, 8:, :]
# autoencoder_train = autoencoder.fit(x_train_new, x_train_new,
#                 nb_epoch=2)

# 可以改（成get_ae）！但是记得要把x_train改成正确的dimension，而且x_test也要同时改了
autoencoder, autoencoder_half = get_ae(input_size)
autoencoder_train = autoencoder.fit(x_train, x_train,
                nb_epoch=100)
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 4202 samples
# Epoch 1/100
# 4202/4202 [==============================] - 1s 137us/sample - loss: -179.2717
# Epoch 2/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -20192.8553
# Epoch 3/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -202539.6641
# Epoch 4/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -878092.7843
# Epoch 5/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -2558833.5420
# Epoch 6/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -5856639.0281
# Epoch 7/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -11444564.0485
# Epoch 8/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -20013059.0062
# Epoch 9/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -32406598.9567
# Epoch 10/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -49305878.6140
# Epoch 11/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -71452672.9786
# Epoch 12/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -99601476.7863
# Epoch 13/100
# 4202/4202 [==============================] - 0s 102us/sample - loss: -134660641.7972
# Epoch 14/100
# 4202/4202 [==============================] - 0s 101us/sample - loss: -177577498.3494
# Epoch 15/100
# 4202/4202 [==============================] - 0s 108us/sample - loss: -228788348.0324
# Epoch 16/100
# 4202/4202 [==============================] - 0s 107us/sample - loss: -289244313.3289
# Epoch 17/100
# 4202/4202 [==============================] - 0s 108us/sample - loss: -360020434.0485
# Epoch 18/100
# 4202/4202 [==============================] - 0s 107us/sample - loss: -441522603.1642
# Epoch 19/100
# 4202/4202 [==============================] - 0s 108us/sample - loss: -534428413.3803
# Epoch 20/100
# 4202/4202 [==============================] - 0s 110us/sample - loss: -639316325.1023
# Epoch 21/100
# 4202/4202 [==============================] - 0s 109us/sample - loss: -756997920.5483
# Epoch 22/100
# 4202/4202 [==============================] - 0s 107us/sample - loss: -888186716.3598
# Epoch 23/100
# 4202/4202 [==============================] - 0s 108us/sample - loss: -1034160648.1637
# Epoch 24/100
# 4202/4202 [==============================] - 0s 111us/sample - loss: -1195317168.5559
# Epoch 25/100
# 4202/4202 [==============================] - 0s 108us/sample - loss: -1371760566.3436
# Epoch 26/100
# 4202/4202 [==============================] - 0s 105us/sample - loss: -1564453485.3270
# Epoch 27/100
# 4202/4202 [==============================] - 0s 111us/sample - loss: -1773573900.5502
# Epoch 28/100
# 4202/4202 [==============================] - 0s 107us/sample - loss: -2001256259.5031
# Epoch 29/100
# 4202/4202 [==============================] - 0s 106us/sample - loss: -2247499411.9219
# Epoch 30/100
# 4202/4202 [==============================] - 0s 107us/sample - loss: -2512314103.9581
# Epoch 31/100
# 4202/4202 [==============================] - 0s 111us/sample - loss: -2797065627.1109
# Epoch 32/100
# 4202/4202 [==============================] - 0s 106us/sample - loss: -3102805422.6064
# Epoch 33/100
# 4202/4202 [==============================] - 0s 112us/sample - loss: -3429742757.4679
# Epoch 34/100
# 4202/4202 [==============================] - 0s 108us/sample - loss: -3779538318.3170
# Epoch 35/100
# 4202/4202 [==============================] - 0s 104us/sample - loss: -4150385078.1609
# Epoch 36/100
# 4202/4202 [==============================] - 0s 110us/sample - loss: -4545401498.5017
# Epoch 37/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -4964151732.2113
# Epoch 38/100
# 4202/4202 [==============================] - 0s 101us/sample - loss: -5407811981.9515
# Epoch 39/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -5877675573.1252
# Epoch 40/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -6374320275.1909
# Epoch 41/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -6897854054.1076
# Epoch 42/100
# 4202/4202 [==============================] - 0s 102us/sample - loss: -7449250088.3313
# Epoch 43/100
# 4202/4202 [==============================] - 0s 95us/sample - loss: -8030375849.2451
# Epoch 44/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -8640497532.1618
# Epoch 45/100
# 4202/4202 [==============================] - 0s 93us/sample - loss: -9280385752.6435
# Epoch 46/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -9951633053.1823
# Epoch 47/100
# 4202/4202 [==============================] - 0s 95us/sample - loss: -10654261517.5250
# Epoch 48/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -11391621705.8391
# Epoch 49/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -12160719685.0871
# Epoch 50/100
# 4202/4202 [==============================] - 0s 105us/sample - loss: -12963440975.3222
# Epoch 51/100
# 4202/4202 [==============================] - 0s 94us/sample - loss: -13801916698.6844
# Epoch 52/100
# 4202/4202 [==============================] - 0s 95us/sample - loss: -14676256985.3746
# Epoch 53/100
# 4202/4202 [==============================] - 0s 94us/sample - loss: -15588428852.1504
# Epoch 54/100
# 4202/4202 [==============================] - 0s 95us/sample - loss: -16536951996.6188
# Epoch 55/100
# 4202/4202 [==============================] - 0s 95us/sample - loss: -17523222506.5550
# Epoch 56/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -18547363221.9933
# Epoch 57/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -19616393477.2394
# Epoch 58/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -20727094748.1771
# Epoch 59/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -21878724056.2780
# Epoch 60/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -23075255047.9200
# Epoch 61/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -24315209816.7044
# Epoch 62/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -25598656508.3446
# Epoch 63/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -26926433474.4674
# Epoch 64/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -28308151972.0057
# Epoch 65/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -29734670911.1166
# Epoch 66/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -31204077639.1585
# Epoch 67/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -32722572337.2261
# Epoch 68/100
# 4202/4202 [==============================] - 0s 103us/sample - loss: -34292955156.4702
# Epoch 69/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -35918938382.9872
# Epoch 70/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -37595614087.6154
# Epoch 71/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -39331168731.6897
# Epoch 72/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -41112004842.9205
# Epoch 73/100
# 4202/4202 [==============================] - 0s 101us/sample - loss: -42954364041.9305
# Epoch 74/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -44847822030.1647
# Epoch 75/100
# 4202/4202 [==============================] - 0s 102us/sample - loss: -46799776090.0447
# Epoch 76/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -48815969868.2761
# Epoch 77/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -50882311740.6797
# Epoch 78/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -53011986854.0771
# Epoch 79/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -55203158250.9205
# Epoch 80/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -57462904739.3965
# Epoch 81/100
# 4202/4202 [==============================] - 0s 101us/sample - loss: -59782453243.1261
# Epoch 82/100
# 4202/4202 [==============================] - 0s 95us/sample - loss: -62158778927.5202
# Epoch 83/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -64606368876.6873
# Epoch 84/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -67114452866.2542
# Epoch 85/100
# 4202/4202 [==============================] - 0s 102us/sample - loss: -69695529072.0990
# Epoch 86/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -72330156654.8805
# Epoch 87/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -75038898820.3256
# Epoch 88/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -77828559298.3456
# Epoch 89/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -80690436907.9867
# Epoch 90/100
# 4202/4202 [==============================] - 0s 102us/sample - loss: -83612835547.5678
# Epoch 91/100
# 4202/4202 [==============================] - 0s 98us/sample - loss: -86616005100.2608
# Epoch 92/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -89702961270.9224
# Epoch 93/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -92863009857.7972
# Epoch 94/100
# 4202/4202 [==============================] - 0s 100us/sample - loss: -96105845611.3470
# Epoch 95/100
# 4202/4202 [==============================] - 0s 101us/sample - loss: -99424683929.6487
# Epoch 96/100
# 4202/4202 [==============================] - 0s 99us/sample - loss: -102820680067.9600
# Epoch 97/100
# 4202/4202 [==============================] - 0s 97us/sample - loss: -106293361619.6478
# Epoch 98/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -109857475054.2104
# Epoch 99/100
# 4202/4202 [==============================] - 0s 96us/sample - loss: -113501739359.8934
# Epoch 100/100
# 4202/4202 [==============================] - 0s 101us/sample - loss: -117226550595.1376

# %% [markdown]
# # Fetch testing data and cluster

# %%
import numpy as np
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score
from sklearn.metrics import v_measure_score, adjusted_rand_score

vms = v_measure_score
nmi = normalized_mutual_info_score
ari = adjusted_rand_score


def acc(y_true, y_pred):
    """
    Calculate clustering accuracy. Require scikit-learn installed

    # Arguments
        y: true labels, numpy.array with shape `(n_samples,)`
        y_pred: predicted labels, numpy.array with shape `(n_samples,)`

    # Return
        accuracy, in [0,1]
    """
    y_true = y_true.astype(np.int64)
    assert y_pred.size == y_true.size
    D = max(y_pred.max(), y_true.max()) + 1
    w = np.zeros((D, D), dtype=np.int64)
    for i in range(y_pred.size):
        w[y_pred[i], y_true[i]] += 1
    from sklearn.utils.linear_assignment_ import linear_assignment
    ind = linear_assignment(w.max() - w)
    return sum([w[i, j] for i, j in ind]) * 1.0 / y_pred.size

# %%
def run_representation_clustering(files, save=False):

  test_comps = files

  (x_test, y_test) = get_csv_test_data(test_comps)
  # if using piano roll, x_test.shape should be n * 1280000, n is the number of 
  # test samples. If using csv, x_test.shape should be n * 776
  print(x_test.shape)
  # x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

  # using autoencoders
  x_test_rep = autoencoder_half.predict(x_test)

  n = len(np.unique(files))

  print(x_test_rep.shape)
  kmeans = KMeans(n_clusters=n, random_state=0).fit(x_test_rep)
  labels = kmeans.labels_
  y_pred = labels

  if save:
    name = "_".join([f[:4] for f in files]) 
    drive_dir = "drive/My Drive/10701/"
    with open(drive_dir + "results/represented_feature/f1/{}.txt".format(name), "w") as f:
      f.write(", ".join([f[:-4] for f in files]) + "\n")
      f.write("acc: {}\n".format(acc(y_test, y_pred)))
      f.write("vms: {}\n".format(vms(y_test, y_pred)))
      f.write("nmi: {}\n".format(nmi(y_test, y_pred)))
      f.write("ari: {}\n".format(ari(y_test, y_pred)))
   
  return acc(y_test, y_pred)

# %%
csv_comps = [alkan_csv, bach_csv, beethoven_csv,
               brahms_csv, buxtehude_csv, byrd_csv, 
               chopin_csv, dandrieu_csv, dvorak_csv, debussy_csv,
               faure_csv, handel_csv, haydn_csv,
               mozart_csv, scarlatti_csv, schubert_csv,
              schumann_csv, scriabin_csv, shostakovich_csv, soler_csv]

# all_pairs = [[a, b] for a in csv_comps for b in csv_comps if (a != b and a > b)]
# for p in list(all_pairs):
# 	print(p)
# 	run_clustering("kmeans", p)
# 	print("done!")
data = []
for a in csv_comps:
	tmp = []
	for b in csv_comps:
		tmp.append(run_representation_clustering([a, b], save=True) )
	data.append(tmp)
data = np.array(data)

# print(run_clustering_features("kmeans", [dandrieu_csv, soler_csv], save=True))
np.savetxt("ae_representation_accuracy.txt", data)
data = np.around(np.loadtxt("ae_representation_accuracy.txt"), decimals=2)

print(data)
# sys.exit()

fig, ax = plt.subplots()
im = ax.imshow(data, cmap="Wistia")

comps_names = [c[:-8] for c in csv_comps]

# We want to show all ticks...
ax.set_xticks(np.arange(len(comps_names)))
ax.set_yticks(np.arange(len(comps_names)))
# ... and label them with the respective list entries
ax.set_xticklabels(comps_names)
ax.set_yticklabels(comps_names)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
          rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(comps_names)):
    for j in range(len(comps_names)):
        text = ax.text(j, i, data[i, j],
                        ha="center", va="center", color="black", size="6")

ax.set_title("heatmap of pairwise composer clustering acc - raw piano roll")
fig.tight_layout()
plt.show()
# Out:
# alkan_all.csv
# alkan_all.csv
# (410, 776)
# (410, 32)
# alkan_all.csv
# bach_all.csv
# (1200, 776)
# (1200, 32)
# alkan_all.csv
# beethoven_all.csv
# (689, 776)
# (689, 32)
# alkan_all.csv
# brahms_all.csv
# (324, 776)
# (324, 32)
# alkan_all.csv
# buxtehude_all.csv
# (277, 776)
# (277, 32)
# alkan_all.csv
# byrd_all.csv
# (307, 776)
# (307, 32)
# alkan_all.csv
# chopin_all.csv
# (359, 776)
# (359, 32)
# alkan_all.csv
# dandrieu_all.csv
# (268, 776)
# (268, 32)
# alkan_all.csv
# dvorak_all.csv
# (272, 776)
# (272, 32)
# alkan_all.csv
# debussy_all.csv
# (384, 776)
# (384, 32)
# alkan_all.csv
# faure_all.csv
# (277, 776)
# (277, 32)
# alkan_all.csv
# handel_all.csv
# (489, 776)
# (489, 32)
# alkan_all.csv
# haydn_all.csv
# (657, 776)
# (657, 32)
# alkan_all.csv
# mozart_all.csv
# (578, 776)
# (578, 32)
# alkan_all.csv
# scarlatti_all.csv
# (760, 776)
# (760, 32)
# alkan_all.csv
# schubert_all.csv
# (393, 776)
# (393, 32)
# alkan_all.csv
# schumann_all.csv
# (272, 776)
# (272, 32)
# alkan_all.csv
# scriabin_all.csv
# (291, 776)
# (291, 32)
# alkan_all.csv
# shostakovich_all.csv
# (309, 776)
# (309, 32)
# alkan_all.csv
# soler_all.csv
# (270, 776)
# (270, 32)
# bach_all.csv
# alkan_all.csv
# (1200, 776)
# (1200, 32)
# bach_all.csv
# bach_all.csv
# (1990, 776)
# (1990, 32)
# bach_all.csv
# beethoven_all.csv
# (1479, 776)
# (1479, 32)
# bach_all.csv
# brahms_all.csv
# (1114, 776)
# (1114, 32)
# bach_all.csv
# buxtehude_all.csv
# (1067, 776)
# (1067, 32)
# bach_all.csv
# byrd_all.csv
# (1097, 776)
# (1097, 32)
# bach_all.csv
# chopin_all.csv
# (1149, 776)
# (1149, 32)
# bach_all.csv
# dandrieu_all.csv
# (1058, 776)
# (1058, 32)
# bach_all.csv
# dvorak_all.csv
# (1062, 776)
# (1062, 32)
# bach_all.csv
# debussy_all.csv
# (1174, 776)
# (1174, 32)
# bach_all.csv
# faure_all.csv
# (1067, 776)
# (1067, 32)
# bach_all.csv
# handel_all.csv
# (1279, 776)
# (1279, 32)
# bach_all.csv
# haydn_all.csv
# (1447, 776)
# (1447, 32)
# bach_all.csv
# mozart_all.csv
# (1368, 776)
# (1368, 32)
# bach_all.csv
# scarlatti_all.csv
# (1550, 776)
# (1550, 32)
# bach_all.csv
# schubert_all.csv
# (1183, 776)
# (1183, 32)
# bach_all.csv
# schumann_all.csv
# (1062, 776)
# (1062, 32)
# bach_all.csv
# scriabin_all.csv
# (1081, 776)
# (1081, 32)
# bach_all.csv
# shostakovich_all.csv
# (1099, 776)
# (1099, 32)
# bach_all.csv
# soler_all.csv
# (1060, 776)
# (1060, 32)
# beethoven_all.csv
# alkan_all.csv
# (689, 776)
# (689, 32)
# beethoven_all.csv
# bach_all.csv
# (1479, 776)
# (1479, 32)
# beethoven_all.csv
# beethoven_all.csv
# (968, 776)
# (968, 32)
# beethoven_all.csv
# brahms_all.csv
# (603, 776)
# (603, 32)
# beethoven_all.csv
# buxtehude_all.csv
# (556, 776)
# (556, 32)
# beethoven_all.csv
# byrd_all.csv
# (586, 776)
# (586, 32)
# beethoven_all.csv
# chopin_all.csv
# (638, 776)
# (638, 32)
# beethoven_all.csv
# dandrieu_all.csv
# (547, 776)
# (547, 32)
# beethoven_all.csv
# dvorak_all.csv
# (551, 776)
# (551, 32)
# beethoven_all.csv
# debussy_all.csv
# (663, 776)
# (663, 32)
# beethoven_all.csv
# faure_all.csv
# (556, 776)
# (556, 32)
# beethoven_all.csv
# handel_all.csv
# (768, 776)
# (768, 32)
# beethoven_all.csv
# haydn_all.csv
# (936, 776)
# (936, 32)
# beethoven_all.csv
# mozart_all.csv
# (857, 776)
# (857, 32)
# beethoven_all.csv
# scarlatti_all.csv
# (1039, 776)
# (1039, 32)
# beethoven_all.csv
# schubert_all.csv
# (672, 776)
# (672, 32)
# beethoven_all.csv
# schumann_all.csv
# (551, 776)
# (551, 32)
# beethoven_all.csv
# scriabin_all.csv
# (570, 776)
# (570, 32)
# beethoven_all.csv
# shostakovich_all.csv
# (588, 776)
# (588, 32)
# beethoven_all.csv
# soler_all.csv
# (549, 776)
# (549, 32)
# brahms_all.csv
# alkan_all.csv
# (324, 776)
# (324, 32)
# brahms_all.csv
# bach_all.csv
# (1114, 776)
# (1114, 32)
# brahms_all.csv
# beethoven_all.csv
# (603, 776)
# (603, 32)
# brahms_all.csv
# brahms_all.csv
# (238, 776)
# (238, 32)
# brahms_all.csv
# buxtehude_all.csv
# (191, 776)
# (191, 32)
# brahms_all.csv
# byrd_all.csv
# (221, 776)
# (221, 32)
# brahms_all.csv
# chopin_all.csv
# (273, 776)
# (273, 32)
# brahms_all.csv
# dandrieu_all.csv
# (182, 776)
# (182, 32)
# brahms_all.csv
# dvorak_all.csv
# (186, 776)
# (186, 32)
# brahms_all.csv
# debussy_all.csv
# (298, 776)
# (298, 32)
# brahms_all.csv
# faure_all.csv
# (191, 776)
# (191, 32)
# brahms_all.csv
# handel_all.csv
# (403, 776)
# (403, 32)
# brahms_all.csv
# haydn_all.csv
# (571, 776)
# (571, 32)
# brahms_all.csv
# mozart_all.csv
# (492, 776)
# (492, 32)
# brahms_all.csv
# scarlatti_all.csv
# (674, 776)
# (674, 32)
# brahms_all.csv
# schubert_all.csv
# (307, 776)
# (307, 32)
# brahms_all.csv
# schumann_all.csv
# (186, 776)
# (186, 32)
# brahms_all.csv
# scriabin_all.csv
# (205, 776)
# (205, 32)
# brahms_all.csv
# shostakovich_all.csv
# (223, 776)
# (223, 32)
# brahms_all.csv
# soler_all.csv
# (184, 776)
# (184, 32)
# buxtehude_all.csv
# alkan_all.csv
# (277, 776)
# (277, 32)
# buxtehude_all.csv
# bach_all.csv
# (1067, 776)
# (1067, 32)
# buxtehude_all.csv
# beethoven_all.csv
# (556, 776)
# (556, 32)
# buxtehude_all.csv
# brahms_all.csv
# (191, 776)
# (191, 32)
# buxtehude_all.csv
# buxtehude_all.csv
# (144, 776)
# (144, 32)
# buxtehude_all.csv
# byrd_all.csv
# (174, 776)
# (174, 32)
# buxtehude_all.csv
# chopin_all.csv
# (226, 776)
# (226, 32)
# buxtehude_all.csv
# dandrieu_all.csv
# (135, 776)
# (135, 32)
# buxtehude_all.csv
# dvorak_all.csv
# (139, 776)
# (139, 32)
# buxtehude_all.csv
# debussy_all.csv
# (251, 776)
# (251, 32)
# buxtehude_all.csv
# faure_all.csv
# (144, 776)
# (144, 32)
# buxtehude_all.csv
# handel_all.csv
# (356, 776)
# (356, 32)
# buxtehude_all.csv
# haydn_all.csv
# (524, 776)
# (524, 32)
# buxtehude_all.csv
# mozart_all.csv
# (445, 776)
# (445, 32)
# buxtehude_all.csv
# scarlatti_all.csv
# (627, 776)
# (627, 32)
# buxtehude_all.csv
# schubert_all.csv
# (260, 776)
# (260, 32)
# buxtehude_all.csv
# schumann_all.csv
# (139, 776)
# (139, 32)
# buxtehude_all.csv
# scriabin_all.csv
# (158, 776)
# (158, 32)
# buxtehude_all.csv
# shostakovich_all.csv
# (176, 776)
# (176, 32)
# buxtehude_all.csv
# soler_all.csv
# (137, 776)
# (137, 32)
# byrd_all.csv
# alkan_all.csv
# (307, 776)
# (307, 32)
# byrd_all.csv
# bach_all.csv
# (1097, 776)
# (1097, 32)
# byrd_all.csv
# beethoven_all.csv
# (586, 776)
# (586, 32)
# byrd_all.csv
# brahms_all.csv
# (221, 776)
# (221, 32)
# byrd_all.csv
# buxtehude_all.csv
# (174, 776)
# (174, 32)
# byrd_all.csv
# byrd_all.csv
# (204, 776)
# (204, 32)
# byrd_all.csv
# chopin_all.csv
# (256, 776)
# (256, 32)
# byrd_all.csv
# dandrieu_all.csv
# (165, 776)
# (165, 32)
# byrd_all.csv
# dvorak_all.csv
# (169, 776)
# (169, 32)
# byrd_all.csv
# debussy_all.csv
# (281, 776)
# (281, 32)
# byrd_all.csv
# faure_all.csv
# (174, 776)
# (174, 32)
# byrd_all.csv
# handel_all.csv
# (386, 776)
# (386, 32)
# byrd_all.csv
# haydn_all.csv
# (554, 776)
# (554, 32)
# byrd_all.csv
# mozart_all.csv
# (475, 776)
# (475, 32)
# byrd_all.csv
# scarlatti_all.csv
# (657, 776)
# (657, 32)
# byrd_all.csv
# schubert_all.csv
# (290, 776)
# (290, 32)
# byrd_all.csv
# schumann_all.csv
# (169, 776)
# (169, 32)
# byrd_all.csv
# scriabin_all.csv
# (188, 776)
# (188, 32)
# byrd_all.csv
# shostakovich_all.csv
# (206, 776)
# (206, 32)
# byrd_all.csv
# soler_all.csv
# (167, 776)
# (167, 32)
# chopin_all.csv
# alkan_all.csv
# (359, 776)
# (359, 32)
# chopin_all.csv
# bach_all.csv
# (1149, 776)
# (1149, 32)
# chopin_all.csv
# beethoven_all.csv
# (638, 776)
# (638, 32)
# chopin_all.csv
# brahms_all.csv
# (273, 776)
# (273, 32)
# chopin_all.csv
# buxtehude_all.csv
# (226, 776)
# (226, 32)
# chopin_all.csv
# byrd_all.csv
# (256, 776)
# (256, 32)
# chopin_all.csv
# chopin_all.csv
# (308, 776)
# (308, 32)
# chopin_all.csv
# dandrieu_all.csv
# (217, 776)
# (217, 32)
# chopin_all.csv
# dvorak_all.csv
# (221, 776)
# (221, 32)
# chopin_all.csv
# debussy_all.csv
# (333, 776)
# (333, 32)
# chopin_all.csv
# faure_all.csv
# (226, 776)
# (226, 32)
# chopin_all.csv
# handel_all.csv
# (438, 776)
# (438, 32)
# chopin_all.csv
# haydn_all.csv
# (606, 776)
# (606, 32)
# chopin_all.csv
# mozart_all.csv
# (527, 776)
# (527, 32)
# chopin_all.csv
# scarlatti_all.csv
# (709, 776)
# (709, 32)
# chopin_all.csv
# schubert_all.csv
# (342, 776)
# (342, 32)
# chopin_all.csv
# schumann_all.csv
# (221, 776)
# (221, 32)
# chopin_all.csv
# scriabin_all.csv
# (240, 776)
# (240, 32)
# chopin_all.csv
# shostakovich_all.csv
# (258, 776)
# (258, 32)
# chopin_all.csv
# soler_all.csv
# (219, 776)
# (219, 32)
# dandrieu_all.csv
# alkan_all.csv
# (268, 776)
# (268, 32)
# dandrieu_all.csv
# bach_all.csv
# (1058, 776)
# (1058, 32)
# dandrieu_all.csv
# beethoven_all.csv
# (547, 776)
# (547, 32)
# dandrieu_all.csv
# brahms_all.csv
# (182, 776)
# (182, 32)
# dandrieu_all.csv
# buxtehude_all.csv
# (135, 776)
# (135, 32)
# dandrieu_all.csv
# byrd_all.csv
# (165, 776)
# (165, 32)
# dandrieu_all.csv
# chopin_all.csv
# (217, 776)
# (217, 32)
# dandrieu_all.csv
# dandrieu_all.csv
# (126, 776)
# (126, 32)
# dandrieu_all.csv
# dvorak_all.csv
# (130, 776)
# (130, 32)
# dandrieu_all.csv
# debussy_all.csv
# (242, 776)
# (242, 32)
# dandrieu_all.csv
# faure_all.csv
# (135, 776)
# (135, 32)
# dandrieu_all.csv
# handel_all.csv
# (347, 776)
# (347, 32)
# dandrieu_all.csv
# haydn_all.csv
# (515, 776)
# (515, 32)
# dandrieu_all.csv
# mozart_all.csv
# (436, 776)
# (436, 32)
# dandrieu_all.csv
# scarlatti_all.csv
# (618, 776)
# (618, 32)
# dandrieu_all.csv
# schubert_all.csv
# (251, 776)
# (251, 32)
# dandrieu_all.csv
# schumann_all.csv
# (130, 776)
# (130, 32)
# dandrieu_all.csv
# scriabin_all.csv
# (149, 776)
# (149, 32)
# dandrieu_all.csv
# shostakovich_all.csv
# (167, 776)
# (167, 32)
# dandrieu_all.csv
# soler_all.csv
# (128, 776)
# (128, 32)
# dvorak_all.csv
# alkan_all.csv
# (272, 776)
# (272, 32)
# dvorak_all.csv
# bach_all.csv
# (1062, 776)
# (1062, 32)
# dvorak_all.csv
# beethoven_all.csv
# (551, 776)
# (551, 32)
# dvorak_all.csv
# brahms_all.csv
# (186, 776)
# (186, 32)
# dvorak_all.csv
# buxtehude_all.csv
# (139, 776)
# (139, 32)
# dvorak_all.csv
# byrd_all.csv
# (169, 776)
# (169, 32)
# dvorak_all.csv
# chopin_all.csv
# (221, 776)
# (221, 32)
# dvorak_all.csv
# dandrieu_all.csv
# (130, 776)
# (130, 32)
# dvorak_all.csv
# dvorak_all.csv
# (134, 776)
# (134, 32)
# dvorak_all.csv
# debussy_all.csv
# (246, 776)
# (246, 32)
# dvorak_all.csv
# faure_all.csv
# (139, 776)
# (139, 32)
# dvorak_all.csv
# handel_all.csv
# (351, 776)
# (351, 32)
# dvorak_all.csv
# haydn_all.csv
# (519, 776)
# (519, 32)
# dvorak_all.csv
# mozart_all.csv
# (440, 776)
# (440, 32)
# dvorak_all.csv
# scarlatti_all.csv
# (622, 776)
# (622, 32)
# dvorak_all.csv
# schubert_all.csv
# (255, 776)
# (255, 32)
# dvorak_all.csv
# schumann_all.csv
# (134, 776)
# (134, 32)
# dvorak_all.csv
# scriabin_all.csv
# (153, 776)
# (153, 32)
# dvorak_all.csv
# shostakovich_all.csv
# (171, 776)
# (171, 32)
# dvorak_all.csv
# soler_all.csv
# (132, 776)
# (132, 32)
# debussy_all.csv
# alkan_all.csv
# (384, 776)
# (384, 32)
# debussy_all.csv
# bach_all.csv
# (1174, 776)
# (1174, 32)
# debussy_all.csv
# beethoven_all.csv
# (663, 776)
# (663, 32)
# debussy_all.csv
# brahms_all.csv
# (298, 776)
# (298, 32)
# debussy_all.csv
# buxtehude_all.csv
# (251, 776)
# (251, 32)
# debussy_all.csv
# byrd_all.csv
# (281, 776)
# (281, 32)
# debussy_all.csv
# chopin_all.csv
# (333, 776)
# (333, 32)
# debussy_all.csv
# dandrieu_all.csv
# (242, 776)
# (242, 32)
# debussy_all.csv
# dvorak_all.csv
# (246, 776)
# (246, 32)
# debussy_all.csv
# debussy_all.csv
# (358, 776)
# (358, 32)
# debussy_all.csv
# faure_all.csv
# (251, 776)
# (251, 32)
# debussy_all.csv
# handel_all.csv
# (463, 776)
# (463, 32)
# debussy_all.csv
# haydn_all.csv
# (631, 776)
# (631, 32)
# debussy_all.csv
# mozart_all.csv
# (552, 776)
# (552, 32)
# debussy_all.csv
# scarlatti_all.csv
# (734, 776)
# (734, 32)
# debussy_all.csv
# schubert_all.csv
# (367, 776)
# (367, 32)
# debussy_all.csv
# schumann_all.csv
# (246, 776)
# (246, 32)
# debussy_all.csv
# scriabin_all.csv
# (265, 776)
# (265, 32)
# debussy_all.csv
# shostakovich_all.csv
# (283, 776)
# (283, 32)
# debussy_all.csv
# soler_all.csv
# (244, 776)
# (244, 32)
# faure_all.csv
# alkan_all.csv
# (277, 776)
# (277, 32)
# faure_all.csv
# bach_all.csv
# (1067, 776)
# (1067, 32)
# faure_all.csv
# beethoven_all.csv
# (556, 776)
# (556, 32)
# faure_all.csv
# brahms_all.csv
# (191, 776)
# (191, 32)
# faure_all.csv
# buxtehude_all.csv
# (144, 776)
# (144, 32)
# faure_all.csv
# byrd_all.csv
# (174, 776)
# (174, 32)
# faure_all.csv
# chopin_all.csv
# (226, 776)
# (226, 32)
# faure_all.csv
# dandrieu_all.csv
# (135, 776)
# (135, 32)
# faure_all.csv
# dvorak_all.csv
# (139, 776)
# (139, 32)
# faure_all.csv
# debussy_all.csv
# (251, 776)
# (251, 32)
# faure_all.csv
# faure_all.csv
# (144, 776)
# (144, 32)
# faure_all.csv
# handel_all.csv
# (356, 776)
# (356, 32)
# faure_all.csv
# haydn_all.csv
# (524, 776)
# (524, 32)
# faure_all.csv
# mozart_all.csv
# (445, 776)
# (445, 32)
# faure_all.csv
# scarlatti_all.csv
# (627, 776)
# (627, 32)
# faure_all.csv
# schubert_all.csv
# (260, 776)
# (260, 32)
# faure_all.csv
# schumann_all.csv
# (139, 776)
# (139, 32)
# faure_all.csv
# scriabin_all.csv
# (158, 776)
# (158, 32)
# faure_all.csv
# shostakovich_all.csv
# (176, 776)
# (176, 32)
# faure_all.csv
# soler_all.csv
# (137, 776)
# (137, 32)
# handel_all.csv
# alkan_all.csv
# (489, 776)
# (489, 32)
# handel_all.csv
# bach_all.csv
# (1279, 776)
# (1279, 32)
# handel_all.csv
# beethoven_all.csv
# (768, 776)
# (768, 32)
# handel_all.csv
# brahms_all.csv
# (403, 776)
# (403, 32)
# handel_all.csv
# buxtehude_all.csv
# (356, 776)
# (356, 32)
# handel_all.csv
# byrd_all.csv
# (386, 776)
# (386, 32)
# handel_all.csv
# chopin_all.csv
# (438, 776)
# (438, 32)
# handel_all.csv
# dandrieu_all.csv
# (347, 776)
# (347, 32)
# handel_all.csv
# dvorak_all.csv
# (351, 776)
# (351, 32)
# handel_all.csv
# debussy_all.csv
# (463, 776)
# (463, 32)
# handel_all.csv
# faure_all.csv
# (356, 776)
# (356, 32)
# handel_all.csv
# handel_all.csv
# (568, 776)
# (568, 32)
# handel_all.csv
# haydn_all.csv
# (736, 776)
# (736, 32)
# handel_all.csv
# mozart_all.csv
# (657, 776)
# (657, 32)
# handel_all.csv
# scarlatti_all.csv
# (839, 776)
# (839, 32)
# handel_all.csv
# schubert_all.csv
# (472, 776)
# (472, 32)
# handel_all.csv
# schumann_all.csv
# (351, 776)
# (351, 32)
# handel_all.csv
# scriabin_all.csv
# (370, 776)
# (370, 32)
# handel_all.csv
# shostakovich_all.csv
# (388, 776)
# (388, 32)
# handel_all.csv
# soler_all.csv
# (349, 776)
# (349, 32)
# haydn_all.csv
# alkan_all.csv
# (657, 776)
# (657, 32)
# haydn_all.csv
# bach_all.csv
# (1447, 776)
# (1447, 32)
# haydn_all.csv
# beethoven_all.csv
# (936, 776)
# (936, 32)
# haydn_all.csv
# brahms_all.csv
# (571, 776)
# (571, 32)
# haydn_all.csv
# buxtehude_all.csv
# (524, 776)
# (524, 32)
# haydn_all.csv
# byrd_all.csv
# (554, 776)
# (554, 32)
# haydn_all.csv
# chopin_all.csv
# (606, 776)
# (606, 32)
# haydn_all.csv
# dandrieu_all.csv
# (515, 776)
# (515, 32)
# haydn_all.csv
# dvorak_all.csv
# (519, 776)
# (519, 32)
# haydn_all.csv
# debussy_all.csv
# (631, 776)
# (631, 32)
# haydn_all.csv
# faure_all.csv
# (524, 776)
# (524, 32)
# haydn_all.csv
# handel_all.csv
# (736, 776)
# (736, 32)
# haydn_all.csv
# haydn_all.csv
# (904, 776)
# (904, 32)
# haydn_all.csv
# mozart_all.csv
# (825, 776)
# (825, 32)
# haydn_all.csv
# scarlatti_all.csv
# (1007, 776)
# (1007, 32)
# haydn_all.csv
# schubert_all.csv
# (640, 776)
# (640, 32)
# haydn_all.csv
# schumann_all.csv
# (519, 776)
# (519, 32)
# haydn_all.csv
# scriabin_all.csv
# (538, 776)
# (538, 32)
# haydn_all.csv
# shostakovich_all.csv
# (556, 776)
# (556, 32)
# haydn_all.csv
# soler_all.csv
# (517, 776)
# (517, 32)
# mozart_all.csv
# alkan_all.csv
# (578, 776)
# (578, 32)
# mozart_all.csv
# bach_all.csv
# (1368, 776)
# (1368, 32)
# mozart_all.csv
# beethoven_all.csv
# (857, 776)
# (857, 32)
# mozart_all.csv
# brahms_all.csv
# (492, 776)
# (492, 32)
# mozart_all.csv
# buxtehude_all.csv
# (445, 776)
# (445, 32)
# mozart_all.csv
# byrd_all.csv
# (475, 776)
# (475, 32)
# mozart_all.csv
# chopin_all.csv
# (527, 776)
# (527, 32)
# mozart_all.csv
# dandrieu_all.csv
# (436, 776)
# (436, 32)
# mozart_all.csv
# dvorak_all.csv
# (440, 776)
# (440, 32)
# mozart_all.csv
# debussy_all.csv
# (552, 776)
# (552, 32)
# mozart_all.csv
# faure_all.csv
# (445, 776)
# (445, 32)
# mozart_all.csv
# handel_all.csv
# (657, 776)
# (657, 32)
# mozart_all.csv
# haydn_all.csv
# (825, 776)
# (825, 32)
# mozart_all.csv
# mozart_all.csv
# (746, 776)
# (746, 32)
# mozart_all.csv
# scarlatti_all.csv
# (928, 776)
# (928, 32)
# mozart_all.csv
# schubert_all.csv
# (561, 776)
# (561, 32)
# mozart_all.csv
# schumann_all.csv
# (440, 776)
# (440, 32)
# mozart_all.csv
# scriabin_all.csv
# (459, 776)
# (459, 32)
# mozart_all.csv
# shostakovich_all.csv
# (477, 776)
# (477, 32)
# mozart_all.csv
# soler_all.csv
# (438, 776)
# (438, 32)
# scarlatti_all.csv
# alkan_all.csv
# (760, 776)
# (760, 32)
# scarlatti_all.csv
# bach_all.csv
# (1550, 776)
# (1550, 32)
# scarlatti_all.csv
# beethoven_all.csv
# (1039, 776)
# (1039, 32)
# scarlatti_all.csv
# brahms_all.csv
# (674, 776)
# (674, 32)
# scarlatti_all.csv
# buxtehude_all.csv
# (627, 776)
# (627, 32)
# scarlatti_all.csv
# byrd_all.csv
# (657, 776)
# (657, 32)
# scarlatti_all.csv
# chopin_all.csv
# (709, 776)
# (709, 32)
# scarlatti_all.csv
# dandrieu_all.csv
# (618, 776)
# (618, 32)
# scarlatti_all.csv
# dvorak_all.csv
# (622, 776)
# (622, 32)
# scarlatti_all.csv
# debussy_all.csv
# (734, 776)
# (734, 32)
# scarlatti_all.csv
# faure_all.csv
# (627, 776)
# (627, 32)
# scarlatti_all.csv
# handel_all.csv
# (839, 776)
# (839, 32)
# scarlatti_all.csv
# haydn_all.csv
# (1007, 776)
# (1007, 32)
# scarlatti_all.csv
# mozart_all.csv
# (928, 776)
# (928, 32)
# scarlatti_all.csv
# scarlatti_all.csv
# (1110, 776)
# (1110, 32)
# scarlatti_all.csv
# schubert_all.csv
# (743, 776)
# (743, 32)
# scarlatti_all.csv
# schumann_all.csv
# (622, 776)
# (622, 32)
# scarlatti_all.csv
# scriabin_all.csv
# (641, 776)
# (641, 32)
# scarlatti_all.csv
# shostakovich_all.csv
# (659, 776)
# (659, 32)
# scarlatti_all.csv
# soler_all.csv
# (620, 776)
# (620, 32)
# schubert_all.csv
# alkan_all.csv
# (393, 776)
# (393, 32)
# schubert_all.csv
# bach_all.csv
# (1183, 776)
# (1183, 32)
# schubert_all.csv
# beethoven_all.csv
# (672, 776)
# (672, 32)
# schubert_all.csv
# brahms_all.csv
# (307, 776)
# (307, 32)
# schubert_all.csv
# buxtehude_all.csv
# (260, 776)
# (260, 32)
# schubert_all.csv
# byrd_all.csv
# (290, 776)
# (290, 32)
# schubert_all.csv
# chopin_all.csv
# (342, 776)
# (342, 32)
# schubert_all.csv
# dandrieu_all.csv
# (251, 776)
# (251, 32)
# schubert_all.csv
# dvorak_all.csv
# (255, 776)
# (255, 32)
# schubert_all.csv
# debussy_all.csv
# (367, 776)
# (367, 32)
# schubert_all.csv
# faure_all.csv
# (260, 776)
# (260, 32)
# schubert_all.csv
# handel_all.csv
# (472, 776)
# (472, 32)
# schubert_all.csv
# haydn_all.csv
# (640, 776)
# (640, 32)
# schubert_all.csv
# mozart_all.csv
# (561, 776)
# (561, 32)
# schubert_all.csv
# scarlatti_all.csv
# (743, 776)
# (743, 32)
# schubert_all.csv
# schubert_all.csv
# (376, 776)
# (376, 32)
# schubert_all.csv
# schumann_all.csv
# (255, 776)
# (255, 32)
# schubert_all.csv
# scriabin_all.csv
# (274, 776)
# (274, 32)
# schubert_all.csv
# shostakovich_all.csv
# (292, 776)
# (292, 32)
# schubert_all.csv
# soler_all.csv
# (253, 776)
# (253, 32)
# schumann_all.csv
# alkan_all.csv
# (272, 776)
# (272, 32)
# schumann_all.csv
# bach_all.csv
# (1062, 776)
# (1062, 32)
# schumann_all.csv
# beethoven_all.csv
# (551, 776)
# (551, 32)
# schumann_all.csv
# brahms_all.csv
# (186, 776)
# (186, 32)
# schumann_all.csv
# buxtehude_all.csv
# (139, 776)
# (139, 32)
# schumann_all.csv
# byrd_all.csv
# (169, 776)
# (169, 32)
# schumann_all.csv
# chopin_all.csv
# (221, 776)
# (221, 32)
# schumann_all.csv
# dandrieu_all.csv
# (130, 776)
# (130, 32)
# schumann_all.csv
# dvorak_all.csv
# (134, 776)
# (134, 32)
# schumann_all.csv
# debussy_all.csv
# (246, 776)
# (246, 32)
# schumann_all.csv
# faure_all.csv
# (139, 776)
# (139, 32)
# schumann_all.csv
# handel_all.csv
# (351, 776)
# (351, 32)
# schumann_all.csv
# haydn_all.csv
# (519, 776)
# (519, 32)
# schumann_all.csv
# mozart_all.csv
# (440, 776)
# (440, 32)
# schumann_all.csv
# scarlatti_all.csv
# (622, 776)
# (622, 32)
# schumann_all.csv
# schubert_all.csv
# (255, 776)
# (255, 32)
# schumann_all.csv
# schumann_all.csv
# (134, 776)
# (134, 32)
# schumann_all.csv
# scriabin_all.csv
# (153, 776)
# (153, 32)
# schumann_all.csv
# shostakovich_all.csv
# (171, 776)
# (171, 32)
# schumann_all.csv
# soler_all.csv
# (132, 776)
# (132, 32)
# scriabin_all.csv
# alkan_all.csv
# (291, 776)
# (291, 32)
# scriabin_all.csv
# bach_all.csv
# (1081, 776)
# (1081, 32)
# scriabin_all.csv
# beethoven_all.csv
# (570, 776)
# (570, 32)
# scriabin_all.csv
# brahms_all.csv
# (205, 776)
# (205, 32)
# scriabin_all.csv
# buxtehude_all.csv
# (158, 776)
# (158, 32)
# scriabin_all.csv
# byrd_all.csv
# (188, 776)
# (188, 32)
# scriabin_all.csv
# chopin_all.csv
# (240, 776)
# (240, 32)
# scriabin_all.csv
# dandrieu_all.csv
# (149, 776)
# (149, 32)
# scriabin_all.csv
# dvorak_all.csv
# (153, 776)
# (153, 32)
# scriabin_all.csv
# debussy_all.csv
# (265, 776)
# (265, 32)
# scriabin_all.csv
# faure_all.csv
# (158, 776)
# (158, 32)
# scriabin_all.csv
# handel_all.csv
# (370, 776)
# (370, 32)
# scriabin_all.csv
# haydn_all.csv
# (538, 776)
# (538, 32)
# scriabin_all.csv
# mozart_all.csv
# (459, 776)
# (459, 32)
# scriabin_all.csv
# scarlatti_all.csv
# (641, 776)
# (641, 32)
# scriabin_all.csv
# schubert_all.csv
# (274, 776)
# (274, 32)
# scriabin_all.csv
# schumann_all.csv
# (153, 776)
# (153, 32)
# scriabin_all.csv
# scriabin_all.csv
# (172, 776)
# (172, 32)
# scriabin_all.csv
# shostakovich_all.csv
# (190, 776)
# (190, 32)
# scriabin_all.csv
# soler_all.csv
# (151, 776)
# (151, 32)
# shostakovich_all.csv
# alkan_all.csv
# (309, 776)
# (309, 32)
# shostakovich_all.csv
# bach_all.csv
# (1099, 776)
# (1099, 32)
# shostakovich_all.csv
# beethoven_all.csv
# (588, 776)
# (588, 32)
# shostakovich_all.csv
# brahms_all.csv
# (223, 776)
# (223, 32)
# shostakovich_all.csv
# buxtehude_all.csv
# (176, 776)
# (176, 32)
# shostakovich_all.csv
# byrd_all.csv
# (206, 776)
# (206, 32)
# shostakovich_all.csv
# chopin_all.csv
# (258, 776)
# (258, 32)
# shostakovich_all.csv
# dandrieu_all.csv
# (167, 776)
# (167, 32)
# shostakovich_all.csv
# dvorak_all.csv
# (171, 776)
# (171, 32)
# shostakovich_all.csv
# debussy_all.csv
# (283, 776)
# (283, 32)
# shostakovich_all.csv
# faure_all.csv
# (176, 776)
# (176, 32)
# shostakovich_all.csv
# handel_all.csv
# (388, 776)
# (388, 32)
# shostakovich_all.csv
# haydn_all.csv
# (556, 776)
# (556, 32)
# shostakovich_all.csv
# mozart_all.csv
# (477, 776)
# (477, 32)
# shostakovich_all.csv
# scarlatti_all.csv
# (659, 776)
# (659, 32)
# shostakovich_all.csv
# schubert_all.csv
# (292, 776)
# (292, 32)
# shostakovich_all.csv
# schumann_all.csv
# (171, 776)
# (171, 32)
# shostakovich_all.csv
# scriabin_all.csv
# (190, 776)
# (190, 32)
# shostakovich_all.csv
# shostakovich_all.csv
# (208, 776)
# (208, 32)
# shostakovich_all.csv
# soler_all.csv
# (169, 776)
# (169, 32)
# soler_all.csv
# alkan_all.csv
# (270, 776)
# (270, 32)
# soler_all.csv
# bach_all.csv
# (1060, 776)
# (1060, 32)
# soler_all.csv
# beethoven_all.csv
# (549, 776)
# (549, 32)
# soler_all.csv
# brahms_all.csv
# (184, 776)
# (184, 32)
# soler_all.csv
# buxtehude_all.csv
# (137, 776)
# (137, 32)
# soler_all.csv
# byrd_all.csv
# (167, 776)
# (167, 32)
# soler_all.csv
# chopin_all.csv
# (219, 776)
# (219, 32)
# soler_all.csv
# dandrieu_all.csv
# (128, 776)
# (128, 32)
# soler_all.csv
# dvorak_all.csv
# (132, 776)
# (132, 32)
# soler_all.csv
# debussy_all.csv
# (244, 776)
# (244, 32)
# soler_all.csv
# faure_all.csv
# (137, 776)
# (137, 32)
# soler_all.csv
# handel_all.csv
# (349, 776)
# (349, 32)
# soler_all.csv
# haydn_all.csv
# (517, 776)
# (517, 32)
# soler_all.csv
# mozart_all.csv
# (438, 776)
# (438, 32)
# soler_all.csv
# scarlatti_all.csv
# (620, 776)
# (620, 32)
# soler_all.csv
# schubert_all.csv
# (253, 776)
# (253, 32)
# soler_all.csv
# schumann_all.csv
# (132, 776)
# (132, 32)
# soler_all.csv
# scriabin_all.csv
# (151, 776)
# (151, 32)
# soler_all.csv
# shostakovich_all.csv
# (169, 776)
# (169, 32)
# soler_all.csv
# soler_all.csv
# (130, 776)
# (130, 32)
# [[0.5  0.53 0.81 0.53 0.65 0.53 0.56 0.56 0.57 0.52 0.57 0.54 0.53 0.51
#   0.66 0.5  0.65 0.55 0.61 0.57]
#  [0.53 0.5  0.64 0.53 0.56 0.51 0.54 0.54 0.54 0.54 0.54 0.51 0.51 0.52
#   0.58 0.53 0.56 0.54 0.56 0.53]
#  [0.81 0.64 0.5  0.86 0.94 0.88 0.86 0.93 0.9  0.83 0.91 0.77 0.73 0.73
#   0.66 0.81 0.93 0.92 0.91 0.92]
#  [0.53 0.53 0.86 0.5  0.66 0.57 0.55 0.55 0.54 0.5  0.56 0.56 0.54 0.55
#   0.66 0.54 0.63 0.55 0.61 0.57]
#  [0.65 0.56 0.94 0.66 0.5  0.78 0.58 0.67 0.67 0.63 0.64 0.65 0.61 0.62
#   0.72 0.67 0.55 0.63 0.53 0.62]
#  [0.53 0.51 0.88 0.57 0.78 0.5  0.63 0.63 0.65 0.56 0.67 0.5  0.51 0.51
#   0.59 0.5  0.76 0.65 0.71 0.62]
#  [0.56 0.54 0.86 0.55 0.58 0.63 0.5  0.53 0.52 0.54 0.51 0.58 0.56 0.56
#   0.7  0.56 0.57 0.51 0.54 0.5 ]
#  [0.56 0.54 0.93 0.55 0.67 0.63 0.53 0.5  0.51 0.54 0.51 0.58 0.55 0.57
#   0.65 0.6  0.65 0.52 0.59 0.52]
#  [0.57 0.54 0.9  0.54 0.67 0.65 0.52 0.51 0.5  0.55 0.53 0.59 0.55 0.57
#   0.67 0.6  0.64 0.51 0.6  0.52]
#  [0.52 0.54 0.83 0.5  0.63 0.56 0.54 0.54 0.55 0.5  0.55 0.56 0.55 0.53
#   0.69 0.53 0.64 0.54 0.58 0.54]
#  [0.57 0.54 0.91 0.56 0.64 0.67 0.51 0.51 0.53 0.55 0.5  0.58 0.55 0.58
#   0.67 0.59 0.63 0.53 0.58 0.5 ]
#  [0.54 0.51 0.77 0.56 0.65 0.5  0.58 0.58 0.59 0.56 0.58 0.5  0.5  0.52
#   0.62 0.54 0.65 0.58 0.61 0.57]
#  [0.53 0.51 0.73 0.54 0.61 0.51 0.56 0.55 0.55 0.55 0.55 0.5  0.5  0.53
#   0.62 0.53 0.62 0.55 0.58 0.55]
#  [0.51 0.52 0.73 0.55 0.62 0.51 0.56 0.57 0.57 0.53 0.58 0.52 0.53 0.5
#   0.66 0.52 0.62 0.57 0.58 0.57]
#  [0.66 0.58 0.66 0.66 0.72 0.59 0.7  0.65 0.67 0.69 0.67 0.62 0.62 0.66
#   0.5  0.67 0.76 0.67 0.7  0.65]
#  [0.5  0.53 0.81 0.54 0.67 0.5  0.56 0.6  0.6  0.53 0.59 0.54 0.53 0.52
#   0.67 0.5  0.67 0.57 0.62 0.58]
#  [0.65 0.56 0.93 0.63 0.55 0.76 0.57 0.65 0.64 0.64 0.63 0.65 0.62 0.62
#   0.76 0.67 0.5  0.59 0.56 0.66]
#  [0.55 0.54 0.92 0.55 0.63 0.65 0.51 0.52 0.51 0.54 0.53 0.58 0.55 0.57
#   0.67 0.57 0.59 0.5  0.57 0.54]
#  [0.61 0.56 0.91 0.61 0.53 0.71 0.54 0.59 0.6  0.58 0.58 0.61 0.58 0.58
#   0.7  0.62 0.56 0.57 0.5  0.57]
#  [0.57 0.53 0.92 0.57 0.62 0.62 0.5  0.52 0.52 0.54 0.5  0.57 0.55 0.57
#   0.65 0.58 0.66 0.54 0.57 0.5 ]]

# %% [markdown]
# # plot latent representation

# %%
from sklearn.manifold import TSNE
def plot_repre(files):

	############################################################
	# Load the data
  X, y = get_csv_test_data(files)

  X = autoencoder_half.predict(X)

	############################################################
	# Fit and transform with a TSNE
  tsne = TSNE(n_components=2, random_state=0)

	############################################################
	# Project the data in 2D
  X_2d = tsne.fit_transform(X)

	############################################################
	# Visualize the data
  target_names = [f[:5] for f in files]
  target_ids = range(len(target_names))
  
  plt.figure(figsize=(6, 5))
  colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'yellow', 'orange', 'purple',
           'pink', 'indigo', 'olive', 'darkred', 'lime', 
           'royalblue', 'grey', 'blueviolet', 'palevioletred', 'yellowgreen']
  colors = colors[:len(target_names)]
  for i, c, label in zip(target_ids, colors, target_names):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c, label=label)
  plt.legend()

  fig_dir = "drive/My Drive/10701/results/fig"
  name = "_".join(target_names)
  plt.savefig("{}/feature_ae_{}.png".format(fig_dir, name))
  plt.show()

plot_repre([alkan_csv, bach_csv, beethoven_csv,
                   brahms_csv, buxtehude_csv, byrd_csv, 
                   chopin_csv, dandrieu_csv, dvorak_csv, debussy_csv,
                   faure_csv, handel_csv, haydn_csv,
                   mozart_csv, scarlatti_csv, schubert_csv,
                  schumann_csv, scriabin_csv, shostakovich_csv, soler_csv])
# Out:
# alkan_all.csv
# bach_all.csv
# beethoven_all.csv
# brahms_all.csv
# buxtehude_all.csv
# byrd_all.csv
# chopin_all.csv
# dandrieu_all.csv
# dvorak_all.csv
# debussy_all.csv
# faure_all.csv
# handel_all.csv
# haydn_all.csv
# mozart_all.csv
# scarlatti_all.csv
# schubert_all.csv
# schumann_all.csv
# scriabin_all.csv
# shostakovich_all.csv
# soler_all.csv
