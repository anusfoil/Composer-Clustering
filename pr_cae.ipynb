# %% [markdown]
# <a href="https://colab.research.google.com/github/Kristin33/Composer-Clustering/blob/master/pr_cae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install pretty_midi

import os, sys
import pretty_midi
import librosa, librosa.display
import matplotlib.pyplot as plt 

from scipy import stats

import numpy as np 
import pandas as pd 

from PIL import Image
from time import time

from sklearn.cluster import SpectralClustering, MeanShift, KMeans, AgglomerativeClustering
# Out:
# Collecting pretty_midi
#   Downloading https://files.pythonhosted.org/packages/bc/8e/63c6e39a7a64623a9cd6aec530070c70827f6f8f40deec938f323d7b1e15/pretty_midi-0.2.9.tar.gz (5.6MB)
#      |████████████████████████████████| 5.6MB 3.2MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from pretty_midi) (1.18.2)
# Collecting mido>=1.1.16
#   Downloading https://files.pythonhosted.org/packages/20/0a/81beb587b1ae832ea6a1901dc7c6faa380e8dd154e0a862f0a9f3d2afab9/mido-1.2.9-py2.py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 8.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from pretty_midi) (1.12.0)
# Building wheels for collected packages: pretty-midi
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-cp36-none-any.whl size=5591953 sha256=3f983ac572d169c9674a5bec82dc1024f0aca0cdfb422d88358c6302f542b7d2
#   Stored in directory: /root/.cache/pip/wheels/4c/a1/c6/b5697841db1112c6e5866d75a6b6bf1bef73b874782556ba66
# Successfully built pretty-midi
# Installing collected packages: mido, pretty-midi
# Successfully installed mido-1.2.9 pretty-midi-0.2.9

# %% [markdown]
# # Data directories and experiment

# %%
# directory variables 

# 直接的midi数据
alkan_dir = "alkan_(c)contributors-kunstderfuge/"
# bach_dir = "bach_lute_(c)contributors-kunstderfuge/"
bach_dir = "bach_all/"
dandrieu_dir = "dandrieu_(c)contributors-kunstderfuge/"
dvorak_dir = "dvorak_(c)contributors-kunstderfuge/"
scriabin_dir = "scriabin_(c)contributors-kunstderfuge/"
byrd_dir = "byrd_(c)contributors-kunstderfuge/"
faure_dir = "faure_(c)contributors-kunstderfuge/"
buxtehude_dir = "buxtehude_(c)contributors-kunstderfuge/"
# beethoven_dir = "beethoven_iii_(c)contributors-kunstderfuge/"
beethoven_dir = "beethoven_all/"
brahms_dir = "brahms_all/"
schubert_dir = "schubert_all/"
chopin_dir = "chopin_all/"
debussy_dir = "debussy_all/"
handel_dir = "handel_all/"
haydn_dir = "haydn_all/"
scarlatti_dir = "scarlatti_all/"
mozart_dir = "mozart_all/"
schumann_dir = "schumann_(c)contributors-kunstderfuge/"
scriabin_dir = "scriabin_(c)contributors-kunstderfuge/"
shostakovich_dir = "shostakovich_(c)contributors-kunstderfuge/"
soler_dir = "soler_(c)contributors-kunstderfuge/"


train_comps = [alkan_dir, bach_dir, beethoven_dir,
                   brahms_dir, buxtehude_dir, byrd_dir, 
                   chopin_dir, dandrieu_dir, dvorak_dir, debussy_dir,
                   faure_dir, handel_dir, haydn_dir,
                   mozart_dir, scarlatti_dir, schubert_dir,
                  schumann_dir, scriabin_dir, shostakovich_dir, soler_dir]
# test用的是实验里面的
test_comps = [scriabin_dir, buxtehude_dir, byrd_dir]

# %%
# 实验：每一组有什么
# test_comps = [scriabin_dir, buxtehude_dir, byrd_dir]
# 我run过了到e8的这个conv ae的情况，用的是[faure_dir, byrd_dir, mozart_dir]
f1_e1 = [dandrieu_dir, soler_dir]
f1_e2 = [dvorak_dir, schumann_dir]
f1_e3 = [buxtehude_dir, faure_dir]
f1_e4 = [scriabin_dir, byrd_dir]
f1_e5 = [shostakovich_dir, brahms_dir]
f1_e6 = [chopin_dir, debussy_dir]
f1_e7 = [schubert_dir, alkan_dir]
f1_e8 = [handel_dir, mozart_dir]
f1_e9 = [haydn_dir, beethoven_dir]
f1_e10 = [scarlatti_dir, bach_dir]

# TODO: 帮忙code几组实验, 三个人的四个人的，然后搞
f2_e1 = []

# soler 这里面的文件好像都导不出piano roll matrix？

f6 = [dandrieu_dir,
	dvorak_dir, schumann_dir,
	buxtehude_dir, faure_dir,
	scriabin_dir, byrd_dir,
	shostakovich_dir, brahms_dir,
	chopin_dir]

# %%
# files: an array of directories
# load the compositions dataset
# the piano rolls are pre saved in the directory
def load_comps_pianoroll(files):

    import os
    from PIL import Image
    data_dir = "drive/My Drive/10701/pianoroll/"

    composer_label = np.empty((0,))

    x, y = np.empty((0, 128, 1000)), np.empty((0,))
    for idx, comp in enumerate(files):
        print(comp)
        composer_data = np.empty((0, 128, 1000))
        path = data_dir + comp
        for filename in os.listdir(path):
            img = np.asarray(Image.open("{}/{}".format(path, filename)).convert("L"))
            try:
                composer_data = np.append(composer_data, np.expand_dims(img, axis=0), axis=0)
            except:
              pass
        x = np.append(x, composer_data, axis=0)
        y = np.append(y, np.ones((composer_data.shape[0],)) * idx, axis=0)

    # x = np.vstack((data1, data2))
    # y = np.hstack((np.zeros(data1.shape[0]), np.ones(data2.shape[0])))

    # standarize?
    x = stats.zscore(x)
    x = np.nan_to_num(x)


    # reshape it to 128000 
    x = x.reshape((x.shape[0], -1))
    assert x.shape[0] == y.shape[0]

    return x, y

# %% [markdown]
# # Fetch training data for autoencoders

# %%
"""
===========================================================
Auto encoders
===========================================================

Attempt of using autoencoders to encode the pianoroll representation
into a lower dimension latent representation. 

currently, the input of the piano roll is of dimension 1280000


"""

import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %tensorflow_version 1.x
import tensorflow as tf
# from __future__ import print_function
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.datasets import mnist
from tensorflow.keras.regularizers import l1
from tensorflow.keras.optimizers import Adam
from keras import regularizers
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
(x_train, y_train) = load_comps_pianoroll(train_comps)

# x_train = x_train.astype('float32') / 255.0

# x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))

print(x_train.shape)
# Out:
# alkan_(c)contributors-kunstderfuge/
# bach_all/
# beethoven_all/
# brahms_all/
# buxtehude_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# chopin_all/
# dandrieu_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# debussy_all/
# faure_(c)contributors-kunstderfuge/
# handel_all/
# haydn_all/
# mozart_all/
# scarlatti_all/
# schubert_all/
# schumann_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (4554, 128000)

# %% [markdown]
# # Construct Model and Train

# %%
# %tensorflow_version 1.x
# alternative model: Convolutional Autoencoders
from keras.layers import Input, Dense, Reshape, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

def get_conv_ae(input_size):
  # if using piano roll, input_size = 128000, if jSymbolic feature, size is 776 

  input_img = Input(shape=(120, 1000, 1))

  x = Conv2D(16, (5, 5), activation='relu', padding="same")(input_img)
  x = MaxPooling2D((2, 2), padding='same')(x)
  x = Conv2D(8, (5, 5), activation='relu', padding='same')(x)
  x = MaxPooling2D((2, 2), padding='same')(x)
  x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
  x = MaxPooling2D((2, 2), padding='same')(x)
  x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
  encoded = MaxPooling2D((2, 2), padding='same')(x)

  # at this point the representation is (8, 63, 8) i.e. 400000-dimensional
  tmp = Reshape((4032,), input_shape=(8, 63, 8))(encoded)
  hidden_1 = Dense(128, activation='relu')(tmp)
  code = Dense(32, activation='relu')(hidden_1)
  # code should have dimension 32? 
  hidden_2 = Dense(128, activation='relu')(code)
  hidden_3 = Dense(4032, activation='relu')(hidden_2)
  tmp = Reshape((8, 63, 8), input_shape=(4032,))(hidden_3)

  x = Conv2D(8, (3, 3), activation='relu', padding='same')(tmp)
  x = UpSampling2D((2, 2))(x)
  x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
  x = UpSampling2D((2, 2))(x)
  x = Conv2D(8, (5, 5), activation='relu', padding='same')(x)
  x = UpSampling2D((2, 2))(x)
  x = Conv2D(16, (5, 5), activation='relu')(x)
  x = UpSampling2D((2, 2))(x)
  decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

  autoencoder = Model(input_img, decoded)
  autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

  autoencoder_half = Model(input_img, code)

  return autoencoder, autoencoder_half

# %%
# train autoencoder 


# if using piano roll, input_size = 128000, if jSymbolic feature, size is 776 
input_size = 128000


# 可以改（成get_ae）！但是记得要把x_train改成正确的dimension，而且x_test也要同时改了
autoencoder, autoencoder_half = get_conv_ae(input_size)
a = np.reshape(x_train, (len(x_train), 128, 1000, 1))
x_train_new = a[:, 8:, :, :]
# x_train_new = a
autoencoder_train = autoencoder.fit(x_train_new, x_train_new,
                nb_epoch=20)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/20
# 4554/4554 [==============================] - 47s 10ms/step - loss: -2098129361.2609
# Epoch 2/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -733399969700951424.0000
# Epoch 3/20
# 4554/4554 [==============================] - 39s 8ms/step - loss: -3007664572236700844032.0000
# Epoch 4/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -29027007550934944317440.0000
# Epoch 5/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -47381149793847911383040.0000
# Epoch 6/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -63438465948010598629376.0000
# Epoch 7/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -79966980716830417485824.0000
# Epoch 8/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -97406410045635753410560.0000
# Epoch 9/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -116109279103143146160128.0000
# Epoch 10/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -136065977453003120050176.0000
# Epoch 11/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -157396337054580945715200.0000
# Epoch 12/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -179879035492482569732096.0000
# Epoch 13/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -203856597198480099770368.0000
# Epoch 14/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -229112019107762044665856.0000
# Epoch 15/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -255642293994585050841088.0000
# Epoch 16/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -283614640936376707579904.0000
# Epoch 17/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -312812388372914209030144.0000
# Epoch 18/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -343140681627296497401856.0000
# Epoch 19/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -373994287701189717917696.0000
# Epoch 20/20
# 4554/4554 [==============================] - 38s 8ms/step - loss: -405710605757421113573376.0000

# %% [markdown]
# # Fetch testing data and cluster

# %%
import numpy as np
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score
from sklearn.metrics import v_measure_score, adjusted_rand_score

vms = v_measure_score
nmi = normalized_mutual_info_score
ari = adjusted_rand_score


def acc(y_true, y_pred):
    """
    Calculate clustering accuracy. Require scikit-learn installed

    # Arguments
        y: true labels, numpy.array with shape `(n_samples,)`
        y_pred: predicted labels, numpy.array with shape `(n_samples,)`

    # Return
        accuracy, in [0,1]
    """
    y_true = y_true.astype(np.int64)
    assert y_pred.size == y_true.size
    D = max(y_pred.max(), y_true.max()) + 1
    w = np.zeros((D, D), dtype=np.int64)
    for i in range(y_pred.size):
        w[y_pred[i], y_true[i]] += 1
    from sklearn.utils.linear_assignment_ import linear_assignment
    ind = linear_assignment(w.max() - w)
    return sum([w[i, j] for i, j in ind]) * 1.0 / y_pred.size

# %%
def run_representation_clustering(files, save=False):

  test_comps = files

  (x_test, y_test) = load_comps_pianoroll(test_comps)
  # if using piano roll, x_test.shape should be n * 1280000, n is the number of 
  # test samples. If using csv, x_test.shape should be n * 776
  print(x_test.shape)
  # x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

  # using autoencoders
  x_test_new = np.reshape(x_test, (len(x_test), 128, 1000, 1))
  x_test_new = x_test_new[:, 8:, :, :]
  x_test_rep = autoencoder_half.predict(x_test_new)

  n = len(np.unique(files))

  print(x_test_rep.shape)
  kmeans = KMeans(n_clusters=n, random_state=0).fit(x_test_rep)
  labels = kmeans.labels_
  y_pred = labels

  if save:
    name = "_".join([f[:4] for f in files]) 
    drive_dir = "drive/My Drive/10701/"
    with open(drive_dir + "results/represented_pr/f1/{}.txt".format(name), "w") as f:
      f.write(", ".join([f[:-4] for f in files]) + "\n")
      f.write("acc: {}\n".format(acc(y_test, y_pred)))
      f.write("vms: {}\n".format(vms(y_test, y_pred)))
      f.write("nmi: {}\n".format(nmi(y_test, y_pred)))
      f.write("ari: {}\n".format(ari(y_test, y_pred)))
   
  return acc(y_test, y_pred)

# %%
# files = [buxtehude_dir, dvorak_dir]
# run_representation_clustering(files, save=True)

# %%
pr_comps = [alkan_dir, bach_dir, beethoven_dir,
               brahms_dir, buxtehude_dir, byrd_dir, 
               chopin_dir, dandrieu_dir, dvorak_dir, debussy_dir,
               faure_dir, handel_dir, haydn_dir,
               mozart_dir, scarlatti_dir, schubert_dir,
              schumann_dir, scriabin_dir, shostakovich_dir, soler_dir]

# all_pairs = [[a, b] for a in csv_comps for b in csv_comps if (a != b and a > b)]
# for p in list(all_pairs):
# 	print(p)
# 	run_clustering("kmeans", p)
# 	print("done!")
data = []
for a in pr_comps:
	tmp = []
	for b in pr_comps:
		tmp.append(run_representation_clustering([a, b], save=True))
	data.append(tmp)
data = np.array(data)

# print(run_clustering_features("kmeans", [dandrieu_csv, soler_csv], save=True))
np.savetxt("pr_accuracy.txt", data)
data = np.around(np.loadtxt("pr_accuracy.txt"), decimals=2)

print(data)
# sys.exit()

fig, ax = plt.subplots()
im = ax.imshow(data, cmap="Wistia")

comps_names = [c[:-8] for c in csv_comps]

# We want to show all ticks...
ax.set_xticks(np.arange(len(comps_names)))
ax.set_yticks(np.arange(len(comps_names)))
# ... and label them with the respective list entries
ax.set_xticklabels(comps_names)
ax.set_yticklabels(comps_names)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
          rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(comps_names)):
    for j in range(len(comps_names)):
        text = ax.text(j, i, data[i, j],
                        ha="center", va="center", color="black", size="6")

ax.set_title("heatmap of pairwise composer clustering acc - raw piano roll")
fig.tight_layout()
plt.show()

#
# Out:
# alkan_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (408, 128000)
# (408, 32)
# alkan_(c)contributors-kunstderfuge/
# bach_all/
# (1219, 128000)
# (1219, 32)
# alkan_(c)contributors-kunstderfuge/
# beethoven_all/
# (632, 128000)
# (632, 32)
# alkan_(c)contributors-kunstderfuge/
# brahms_all/
# (322, 128000)
# (322, 32)
# alkan_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (273, 128000)
# (273, 32)
# alkan_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (306, 128000)
# (306, 32)
# alkan_(c)contributors-kunstderfuge/
# chopin_all/
# (351, 128000)
# (351, 32)
# alkan_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (267, 128000)
# (267, 32)
# alkan_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (269, 128000)
# (269, 32)
# alkan_(c)contributors-kunstderfuge/
# debussy_all/
# (381, 128000)
# (381, 32)
# alkan_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (274, 128000)
# (274, 32)
# alkan_(c)contributors-kunstderfuge/
# handel_all/
# (460, 128000)
# (460, 32)
# alkan_(c)contributors-kunstderfuge/
# haydn_all/
# (652, 128000)
# (652, 32)
# alkan_(c)contributors-kunstderfuge/
# mozart_all/
# (552, 128000)
# (552, 32)
# alkan_(c)contributors-kunstderfuge/
# scarlatti_all/
# (759, 128000)
# (759, 32)
# alkan_(c)contributors-kunstderfuge/
# schubert_all/
# (387, 128000)
# (387, 32)
# alkan_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (272, 128000)
# (272, 32)
# alkan_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (289, 128000)
# (289, 32)
# alkan_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (304, 128000)
# (304, 32)
# alkan_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (257, 128000)
# (257, 32)
# bach_all/
# alkan_(c)contributors-kunstderfuge/
# (1219, 128000)
# (1219, 32)
# bach_all/
# bach_all/
# (2030, 128000)
# (2030, 32)
# bach_all/
# beethoven_all/
# (1443, 128000)
# (1443, 32)
# bach_all/
# brahms_all/
# (1133, 128000)
# (1133, 32)
# bach_all/
# buxtehude_(c)contributors-kunstderfuge/
# (1084, 128000)
# (1084, 32)
# bach_all/
# byrd_(c)contributors-kunstderfuge/
# (1117, 128000)
# (1117, 32)
# bach_all/
# chopin_all/
# (1162, 128000)
# (1162, 32)
# bach_all/
# dandrieu_(c)contributors-kunstderfuge/
# (1078, 128000)
# (1078, 32)
# bach_all/
# dvorak_(c)contributors-kunstderfuge/
# (1080, 128000)
# (1080, 32)
# bach_all/
# debussy_all/
# (1192, 128000)
# (1192, 32)
# bach_all/
# faure_(c)contributors-kunstderfuge/
# (1085, 128000)
# (1085, 32)
# bach_all/
# handel_all/
# (1271, 128000)
# (1271, 32)
# bach_all/
# haydn_all/
# (1463, 128000)
# (1463, 32)
# bach_all/
# mozart_all/
# (1363, 128000)
# (1363, 32)
# bach_all/
# scarlatti_all/
# (1570, 128000)
# (1570, 32)
# bach_all/
# schubert_all/
# (1198, 128000)
# (1198, 32)
# bach_all/
# schumann_(c)contributors-kunstderfuge/
# (1083, 128000)
# (1083, 32)
# bach_all/
# scriabin_(c)contributors-kunstderfuge/
# (1100, 128000)
# (1100, 32)
# bach_all/
# shostakovich_(c)contributors-kunstderfuge/
# (1115, 128000)
# (1115, 32)
# bach_all/
# soler_(c)contributors-kunstderfuge/
# (1068, 128000)
# (1068, 32)
# beethoven_all/
# alkan_(c)contributors-kunstderfuge/
# (632, 128000)
# (632, 32)
# beethoven_all/
# bach_all/
# (1443, 128000)
# (1443, 32)
# beethoven_all/
# beethoven_all/
# (856, 128000)
# (856, 32)
# beethoven_all/
# brahms_all/
# (546, 128000)
# (546, 32)
# beethoven_all/
# buxtehude_(c)contributors-kunstderfuge/
# (497, 128000)
# (497, 32)
# beethoven_all/
# byrd_(c)contributors-kunstderfuge/
# (530, 128000)
# (530, 32)
# beethoven_all/
# chopin_all/
# (575, 128000)
# (575, 32)
# beethoven_all/
# dandrieu_(c)contributors-kunstderfuge/
# (491, 128000)
# (491, 32)
# beethoven_all/
# dvorak_(c)contributors-kunstderfuge/
# (493, 128000)
# (493, 32)
# beethoven_all/
# debussy_all/
# (605, 128000)
# (605, 32)
# beethoven_all/
# faure_(c)contributors-kunstderfuge/
# (498, 128000)
# (498, 32)
# beethoven_all/
# handel_all/
# (684, 128000)
# (684, 32)
# beethoven_all/
# haydn_all/
# (876, 128000)
# (876, 32)
# beethoven_all/
# mozart_all/
# (776, 128000)
# (776, 32)
# beethoven_all/
# scarlatti_all/
# (983, 128000)
# (983, 32)
# beethoven_all/
# schubert_all/
# (611, 128000)
# (611, 32)
# beethoven_all/
# schumann_(c)contributors-kunstderfuge/
# (496, 128000)
# (496, 32)
# beethoven_all/
# scriabin_(c)contributors-kunstderfuge/
# (513, 128000)
# (513, 32)
# beethoven_all/
# shostakovich_(c)contributors-kunstderfuge/
# (528, 128000)
# (528, 32)
# beethoven_all/
# soler_(c)contributors-kunstderfuge/
# (481, 128000)
# (481, 32)
# brahms_all/
# alkan_(c)contributors-kunstderfuge/
# (322, 128000)
# (322, 32)
# brahms_all/
# bach_all/
# (1133, 128000)
# (1133, 32)
# brahms_all/
# beethoven_all/
# (546, 128000)
# (546, 32)
# brahms_all/
# brahms_all/
# (236, 128000)
# (236, 32)
# brahms_all/
# buxtehude_(c)contributors-kunstderfuge/
# (187, 128000)
# (187, 32)
# brahms_all/
# byrd_(c)contributors-kunstderfuge/
# (220, 128000)
# (220, 32)
# brahms_all/
# chopin_all/
# (265, 128000)
# (265, 32)
# brahms_all/
# dandrieu_(c)contributors-kunstderfuge/
# (181, 128000)
# (181, 32)
# brahms_all/
# dvorak_(c)contributors-kunstderfuge/
# (183, 128000)
# (183, 32)
# brahms_all/
# debussy_all/
# (295, 128000)
# (295, 32)
# brahms_all/
# faure_(c)contributors-kunstderfuge/
# (188, 128000)
# (188, 32)
# brahms_all/
# handel_all/
# (374, 128000)
# (374, 32)
# brahms_all/
# haydn_all/
# (566, 128000)
# (566, 32)
# brahms_all/
# mozart_all/
# (466, 128000)
# (466, 32)
# brahms_all/
# scarlatti_all/
# (673, 128000)
# (673, 32)
# brahms_all/
# schubert_all/
# (301, 128000)
# (301, 32)
# brahms_all/
# schumann_(c)contributors-kunstderfuge/
# (186, 128000)
# (186, 32)
# brahms_all/
# scriabin_(c)contributors-kunstderfuge/
# (203, 128000)
# (203, 32)
# brahms_all/
# shostakovich_(c)contributors-kunstderfuge/
# (218, 128000)
# (218, 32)
# brahms_all/
# soler_(c)contributors-kunstderfuge/
# (171, 128000)
# (171, 32)
# buxtehude_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (273, 128000)
# (273, 32)
# buxtehude_(c)contributors-kunstderfuge/
# bach_all/
# (1084, 128000)
# (1084, 32)
# buxtehude_(c)contributors-kunstderfuge/
# beethoven_all/
# (497, 128000)
# (497, 32)
# buxtehude_(c)contributors-kunstderfuge/
# brahms_all/
# (187, 128000)
# (187, 32)
# buxtehude_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (138, 128000)
# (138, 32)
# buxtehude_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (171, 128000)
# (171, 32)
# buxtehude_(c)contributors-kunstderfuge/
# chopin_all/
# (216, 128000)
# (216, 32)
# buxtehude_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (132, 128000)
# (132, 32)
# buxtehude_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (134, 128000)
# (134, 32)
# buxtehude_(c)contributors-kunstderfuge/
# debussy_all/
# (246, 128000)
# (246, 32)
# buxtehude_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (139, 128000)
# (139, 32)
# buxtehude_(c)contributors-kunstderfuge/
# handel_all/
# (325, 128000)
# (325, 32)
# buxtehude_(c)contributors-kunstderfuge/
# haydn_all/
# (517, 128000)
# (517, 32)
# buxtehude_(c)contributors-kunstderfuge/
# mozart_all/
# (417, 128000)
# (417, 32)
# buxtehude_(c)contributors-kunstderfuge/
# scarlatti_all/
# (624, 128000)
# (624, 32)
# buxtehude_(c)contributors-kunstderfuge/
# schubert_all/
# (252, 128000)
# (252, 32)
# buxtehude_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (137, 128000)
# (137, 32)
# buxtehude_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (154, 128000)
# (154, 32)
# buxtehude_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (169, 128000)
# (169, 32)
# buxtehude_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (122, 128000)
# (122, 32)
# byrd_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (306, 128000)
# (306, 32)
# byrd_(c)contributors-kunstderfuge/
# bach_all/
# (1117, 128000)
# (1117, 32)
# byrd_(c)contributors-kunstderfuge/
# beethoven_all/
# (530, 128000)
# (530, 32)
# byrd_(c)contributors-kunstderfuge/
# brahms_all/
# (220, 128000)
# (220, 32)
# byrd_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (171, 128000)
# (171, 32)
# byrd_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (204, 128000)
# (204, 32)
# byrd_(c)contributors-kunstderfuge/
# chopin_all/
# (249, 128000)
# (249, 32)
# byrd_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (165, 128000)
# (165, 32)
# byrd_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (167, 128000)
# (167, 32)
# byrd_(c)contributors-kunstderfuge/
# debussy_all/
# (279, 128000)
# (279, 32)
# byrd_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (172, 128000)
# (172, 32)
# byrd_(c)contributors-kunstderfuge/
# handel_all/
# (358, 128000)
# (358, 32)
# byrd_(c)contributors-kunstderfuge/
# haydn_all/
# (550, 128000)
# (550, 32)
# byrd_(c)contributors-kunstderfuge/
# mozart_all/
# (450, 128000)
# (450, 32)
# byrd_(c)contributors-kunstderfuge/
# scarlatti_all/
# (657, 128000)
# (657, 32)
# byrd_(c)contributors-kunstderfuge/
# schubert_all/
# (285, 128000)
# (285, 32)
# byrd_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (170, 128000)
# (170, 32)
# byrd_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (187, 128000)
# (187, 32)
# byrd_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (202, 128000)
# (202, 32)
# byrd_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (155, 128000)
# (155, 32)
# chopin_all/
# alkan_(c)contributors-kunstderfuge/
# (351, 128000)
# (351, 32)
# chopin_all/
# bach_all/
# (1162, 128000)
# (1162, 32)
# chopin_all/
# beethoven_all/
# (575, 128000)
# (575, 32)
# chopin_all/
# brahms_all/
# (265, 128000)
# (265, 32)
# chopin_all/
# buxtehude_(c)contributors-kunstderfuge/
# (216, 128000)
# (216, 32)
# chopin_all/
# byrd_(c)contributors-kunstderfuge/
# (249, 128000)
# (249, 32)
# chopin_all/
# chopin_all/
# (294, 128000)
# (294, 32)
# chopin_all/
# dandrieu_(c)contributors-kunstderfuge/
# (210, 128000)
# (210, 32)
# chopin_all/
# dvorak_(c)contributors-kunstderfuge/
# (212, 128000)
# (212, 32)
# chopin_all/
# debussy_all/
# (324, 128000)
# (324, 32)
# chopin_all/
# faure_(c)contributors-kunstderfuge/
# (217, 128000)
# (217, 32)
# chopin_all/
# handel_all/
# (403, 128000)
# (403, 32)
# chopin_all/
# haydn_all/
# (595, 128000)
# (595, 32)
# chopin_all/
# mozart_all/
# (495, 128000)
# (495, 32)
# chopin_all/
# scarlatti_all/
# (702, 128000)
# (702, 32)
# chopin_all/
# schubert_all/
# (330, 128000)
# (330, 32)
# chopin_all/
# schumann_(c)contributors-kunstderfuge/
# (215, 128000)
# (215, 32)
# chopin_all/
# scriabin_(c)contributors-kunstderfuge/
# (232, 128000)
# (232, 32)
# chopin_all/
# shostakovich_(c)contributors-kunstderfuge/
# (247, 128000)
# (247, 32)
# chopin_all/
# soler_(c)contributors-kunstderfuge/
# (200, 128000)
# (200, 32)
# dandrieu_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (267, 128000)
# (267, 32)
# dandrieu_(c)contributors-kunstderfuge/
# bach_all/
# (1078, 128000)
# (1078, 32)
# dandrieu_(c)contributors-kunstderfuge/
# beethoven_all/
# (491, 128000)
# (491, 32)
# dandrieu_(c)contributors-kunstderfuge/
# brahms_all/
# (181, 128000)
# (181, 32)
# dandrieu_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (132, 128000)
# (132, 32)
# dandrieu_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (165, 128000)
# (165, 32)
# dandrieu_(c)contributors-kunstderfuge/
# chopin_all/
# (210, 128000)
# (210, 32)
# dandrieu_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (126, 128000)
# (126, 32)
# dandrieu_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (128, 128000)
# (128, 32)
# dandrieu_(c)contributors-kunstderfuge/
# debussy_all/
# (240, 128000)
# (240, 32)
# dandrieu_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (133, 128000)
# (133, 32)
# dandrieu_(c)contributors-kunstderfuge/
# handel_all/
# (319, 128000)
# (319, 32)
# dandrieu_(c)contributors-kunstderfuge/
# haydn_all/
# (511, 128000)
# (511, 32)
# dandrieu_(c)contributors-kunstderfuge/
# mozart_all/
# (411, 128000)
# (411, 32)
# dandrieu_(c)contributors-kunstderfuge/
# scarlatti_all/
# (618, 128000)
# (618, 32)
# dandrieu_(c)contributors-kunstderfuge/
# schubert_all/
# (246, 128000)
# (246, 32)
# dandrieu_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (131, 128000)
# (131, 32)
# dandrieu_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (148, 128000)
# (148, 32)
# dandrieu_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (163, 128000)
# (163, 32)
# dandrieu_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (116, 128000)
# (116, 32)
# dvorak_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (269, 128000)
# (269, 32)
# dvorak_(c)contributors-kunstderfuge/
# bach_all/
# (1080, 128000)
# (1080, 32)
# dvorak_(c)contributors-kunstderfuge/
# beethoven_all/
# (493, 128000)
# (493, 32)
# dvorak_(c)contributors-kunstderfuge/
# brahms_all/
# (183, 128000)
# (183, 32)
# dvorak_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (134, 128000)
# (134, 32)
# dvorak_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (167, 128000)
# (167, 32)
# dvorak_(c)contributors-kunstderfuge/
# chopin_all/
# (212, 128000)
# (212, 32)
# dvorak_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (128, 128000)
# (128, 32)
# dvorak_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (130, 128000)
# (130, 32)
# dvorak_(c)contributors-kunstderfuge/
# debussy_all/
# (242, 128000)
# (242, 32)
# dvorak_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (135, 128000)
# (135, 32)
# dvorak_(c)contributors-kunstderfuge/
# handel_all/
# (321, 128000)
# (321, 32)
# dvorak_(c)contributors-kunstderfuge/
# haydn_all/
# (513, 128000)
# (513, 32)
# dvorak_(c)contributors-kunstderfuge/
# mozart_all/
# (413, 128000)
# (413, 32)
# dvorak_(c)contributors-kunstderfuge/
# scarlatti_all/
# (620, 128000)
# (620, 32)
# dvorak_(c)contributors-kunstderfuge/
# schubert_all/
# (248, 128000)
# (248, 32)
# dvorak_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (133, 128000)
# (133, 32)
# dvorak_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (150, 128000)
# (150, 32)
# dvorak_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (165, 128000)
# (165, 32)
# dvorak_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (118, 128000)
# (118, 32)
# debussy_all/
# alkan_(c)contributors-kunstderfuge/
# (381, 128000)
# (381, 32)
# debussy_all/
# bach_all/
# (1192, 128000)
# (1192, 32)
# debussy_all/
# beethoven_all/
# (605, 128000)
# (605, 32)
# debussy_all/
# brahms_all/
# (295, 128000)
# (295, 32)
# debussy_all/
# buxtehude_(c)contributors-kunstderfuge/
# (246, 128000)
# (246, 32)
# debussy_all/
# byrd_(c)contributors-kunstderfuge/
# (279, 128000)
# (279, 32)
# debussy_all/
# chopin_all/
# (324, 128000)
# (324, 32)
# debussy_all/
# dandrieu_(c)contributors-kunstderfuge/
# (240, 128000)
# (240, 32)
# debussy_all/
# dvorak_(c)contributors-kunstderfuge/
# (242, 128000)
# (242, 32)
# debussy_all/
# debussy_all/
# (354, 128000)
# (354, 32)
# debussy_all/
# faure_(c)contributors-kunstderfuge/
# (247, 128000)
# (247, 32)
# debussy_all/
# handel_all/
# (433, 128000)
# (433, 32)
# debussy_all/
# haydn_all/
# (625, 128000)
# (625, 32)
# debussy_all/
# mozart_all/
# (525, 128000)
# (525, 32)
# debussy_all/
# scarlatti_all/
# (732, 128000)
# (732, 32)
# debussy_all/
# schubert_all/
# (360, 128000)
# (360, 32)
# debussy_all/
# schumann_(c)contributors-kunstderfuge/
# (245, 128000)
# (245, 32)
# debussy_all/
# scriabin_(c)contributors-kunstderfuge/
# (262, 128000)
# (262, 32)
# debussy_all/
# shostakovich_(c)contributors-kunstderfuge/
# (277, 128000)
# (277, 32)
# debussy_all/
# soler_(c)contributors-kunstderfuge/
# (230, 128000)
# (230, 32)
# faure_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (274, 128000)
# (274, 32)
# faure_(c)contributors-kunstderfuge/
# bach_all/
# (1085, 128000)
# (1085, 32)
# faure_(c)contributors-kunstderfuge/
# beethoven_all/
# (498, 128000)
# (498, 32)
# faure_(c)contributors-kunstderfuge/
# brahms_all/
# (188, 128000)
# (188, 32)
# faure_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (139, 128000)
# (139, 32)
# faure_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (172, 128000)
# (172, 32)
# faure_(c)contributors-kunstderfuge/
# chopin_all/
# (217, 128000)
# (217, 32)
# faure_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (133, 128000)
# (133, 32)
# faure_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (135, 128000)
# (135, 32)
# faure_(c)contributors-kunstderfuge/
# debussy_all/
# (247, 128000)
# (247, 32)
# faure_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (140, 128000)
# (140, 32)
# faure_(c)contributors-kunstderfuge/
# handel_all/
# (326, 128000)
# (326, 32)
# faure_(c)contributors-kunstderfuge/
# haydn_all/
# (518, 128000)
# (518, 32)
# faure_(c)contributors-kunstderfuge/
# mozart_all/
# (418, 128000)
# (418, 32)
# faure_(c)contributors-kunstderfuge/
# scarlatti_all/
# (625, 128000)
# (625, 32)
# faure_(c)contributors-kunstderfuge/
# schubert_all/
# (253, 128000)
# (253, 32)
# faure_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (138, 128000)
# (138, 32)
# faure_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (155, 128000)
# (155, 32)
# faure_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (170, 128000)
# (170, 32)
# faure_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (123, 128000)
# (123, 32)
# handel_all/
# alkan_(c)contributors-kunstderfuge/
# (460, 128000)
# (460, 32)
# handel_all/
# bach_all/
# (1271, 128000)
# (1271, 32)
# handel_all/
# beethoven_all/
# (684, 128000)
# (684, 32)
# handel_all/
# brahms_all/
# (374, 128000)
# (374, 32)
# handel_all/
# buxtehude_(c)contributors-kunstderfuge/
# (325, 128000)
# (325, 32)
# handel_all/
# byrd_(c)contributors-kunstderfuge/
# (358, 128000)
# (358, 32)
# handel_all/
# chopin_all/
# (403, 128000)
# (403, 32)
# handel_all/
# dandrieu_(c)contributors-kunstderfuge/
# (319, 128000)
# (319, 32)
# handel_all/
# dvorak_(c)contributors-kunstderfuge/
# (321, 128000)
# (321, 32)
# handel_all/
# debussy_all/
# (433, 128000)
# (433, 32)
# handel_all/
# faure_(c)contributors-kunstderfuge/
# (326, 128000)
# (326, 32)
# handel_all/
# handel_all/
# (512, 128000)
# (512, 32)
# handel_all/
# haydn_all/
# (704, 128000)
# (704, 32)
# handel_all/
# mozart_all/
# (604, 128000)
# (604, 32)
# handel_all/
# scarlatti_all/
# (811, 128000)
# (811, 32)
# handel_all/
# schubert_all/
# (439, 128000)
# (439, 32)
# handel_all/
# schumann_(c)contributors-kunstderfuge/
# (324, 128000)
# (324, 32)
# handel_all/
# scriabin_(c)contributors-kunstderfuge/
# (341, 128000)
# (341, 32)
# handel_all/
# shostakovich_(c)contributors-kunstderfuge/
# (356, 128000)
# (356, 32)
# handel_all/
# soler_(c)contributors-kunstderfuge/
# (309, 128000)
# (309, 32)
# haydn_all/
# alkan_(c)contributors-kunstderfuge/
# (652, 128000)
# (652, 32)
# haydn_all/
# bach_all/
# (1463, 128000)
# (1463, 32)
# haydn_all/
# beethoven_all/
# (876, 128000)
# (876, 32)
# haydn_all/
# brahms_all/
# (566, 128000)
# (566, 32)
# haydn_all/
# buxtehude_(c)contributors-kunstderfuge/
# (517, 128000)
# (517, 32)
# haydn_all/
# byrd_(c)contributors-kunstderfuge/
# (550, 128000)
# (550, 32)
# haydn_all/
# chopin_all/
# (595, 128000)
# (595, 32)
# haydn_all/
# dandrieu_(c)contributors-kunstderfuge/
# (511, 128000)
# (511, 32)
# haydn_all/
# dvorak_(c)contributors-kunstderfuge/
# (513, 128000)
# (513, 32)
# haydn_all/
# debussy_all/
# (625, 128000)
# (625, 32)
# haydn_all/
# faure_(c)contributors-kunstderfuge/
# (518, 128000)
# (518, 32)
# haydn_all/
# handel_all/
# (704, 128000)
# (704, 32)
# haydn_all/
# haydn_all/
# (896, 128000)
# (896, 32)
# haydn_all/
# mozart_all/
# (796, 128000)
# (796, 32)
# haydn_all/
# scarlatti_all/
# (1003, 128000)
# (1003, 32)
# haydn_all/
# schubert_all/
# (631, 128000)
# (631, 32)
# haydn_all/
# schumann_(c)contributors-kunstderfuge/
# (516, 128000)
# (516, 32)
# haydn_all/
# scriabin_(c)contributors-kunstderfuge/
# (533, 128000)
# (533, 32)
# haydn_all/
# shostakovich_(c)contributors-kunstderfuge/
# (548, 128000)
# (548, 32)
# haydn_all/
# soler_(c)contributors-kunstderfuge/
# (501, 128000)
# (501, 32)
# mozart_all/
# alkan_(c)contributors-kunstderfuge/
# (552, 128000)
# (552, 32)
# mozart_all/
# bach_all/
# (1363, 128000)
# (1363, 32)
# mozart_all/
# beethoven_all/
# (776, 128000)
# (776, 32)
# mozart_all/
# brahms_all/
# (466, 128000)
# (466, 32)
# mozart_all/
# buxtehude_(c)contributors-kunstderfuge/
# (417, 128000)
# (417, 32)
# mozart_all/
# byrd_(c)contributors-kunstderfuge/
# (450, 128000)
# (450, 32)
# mozart_all/
# chopin_all/
# (495, 128000)
# (495, 32)
# mozart_all/
# dandrieu_(c)contributors-kunstderfuge/
# (411, 128000)
# (411, 32)
# mozart_all/
# dvorak_(c)contributors-kunstderfuge/
# (413, 128000)
# (413, 32)
# mozart_all/
# debussy_all/
# (525, 128000)
# (525, 32)
# mozart_all/
# faure_(c)contributors-kunstderfuge/
# (418, 128000)
# (418, 32)
# mozart_all/
# handel_all/
# (604, 128000)
# (604, 32)
# mozart_all/
# haydn_all/
# (796, 128000)
# (796, 32)
# mozart_all/
# mozart_all/
# (696, 128000)
# (696, 32)
# mozart_all/
# scarlatti_all/
# (903, 128000)
# (903, 32)
# mozart_all/
# schubert_all/
# (531, 128000)
# (531, 32)
# mozart_all/
# schumann_(c)contributors-kunstderfuge/
# (416, 128000)
# (416, 32)
# mozart_all/
# scriabin_(c)contributors-kunstderfuge/
# (433, 128000)
# (433, 32)
# mozart_all/
# shostakovich_(c)contributors-kunstderfuge/
# (448, 128000)
# (448, 32)
# mozart_all/
# soler_(c)contributors-kunstderfuge/
# (401, 128000)
# (401, 32)
# scarlatti_all/
# alkan_(c)contributors-kunstderfuge/
# (759, 128000)
# (759, 32)
# scarlatti_all/
# bach_all/
# (1570, 128000)
# (1570, 32)
# scarlatti_all/
# beethoven_all/
# (983, 128000)
# (983, 32)
# scarlatti_all/
# brahms_all/
# (673, 128000)
# (673, 32)
# scarlatti_all/
# buxtehude_(c)contributors-kunstderfuge/
# (624, 128000)
# (624, 32)
# scarlatti_all/
# byrd_(c)contributors-kunstderfuge/
# (657, 128000)
# (657, 32)
# scarlatti_all/
# chopin_all/
# (702, 128000)
# (702, 32)
# scarlatti_all/
# dandrieu_(c)contributors-kunstderfuge/
# (618, 128000)
# (618, 32)
# scarlatti_all/
# dvorak_(c)contributors-kunstderfuge/
# (620, 128000)
# (620, 32)
# scarlatti_all/
# debussy_all/
# (732, 128000)
# (732, 32)
# scarlatti_all/
# faure_(c)contributors-kunstderfuge/
# (625, 128000)
# (625, 32)
# scarlatti_all/
# handel_all/
# (811, 128000)
# (811, 32)
# scarlatti_all/
# haydn_all/
# (1003, 128000)
# (1003, 32)
# scarlatti_all/
# mozart_all/
# (903, 128000)
# (903, 32)
# scarlatti_all/
# scarlatti_all/
# (1110, 128000)
# (1110, 32)
# scarlatti_all/
# schubert_all/
# (738, 128000)
# (738, 32)
# scarlatti_all/
# schumann_(c)contributors-kunstderfuge/
# (623, 128000)
# (623, 32)
# scarlatti_all/
# scriabin_(c)contributors-kunstderfuge/
# (640, 128000)
# (640, 32)
# scarlatti_all/
# shostakovich_(c)contributors-kunstderfuge/
# (655, 128000)
# (655, 32)
# scarlatti_all/
# soler_(c)contributors-kunstderfuge/
# (608, 128000)
# (608, 32)
# schubert_all/
# alkan_(c)contributors-kunstderfuge/
# (387, 128000)
# (387, 32)
# schubert_all/
# bach_all/
# (1198, 128000)
# (1198, 32)
# schubert_all/
# beethoven_all/
# (611, 128000)
# (611, 32)
# schubert_all/
# brahms_all/
# (301, 128000)
# (301, 32)
# schubert_all/
# buxtehude_(c)contributors-kunstderfuge/
# (252, 128000)
# (252, 32)
# schubert_all/
# byrd_(c)contributors-kunstderfuge/
# (285, 128000)
# (285, 32)
# schubert_all/
# chopin_all/
# (330, 128000)
# (330, 32)
# schubert_all/
# dandrieu_(c)contributors-kunstderfuge/
# (246, 128000)
# (246, 32)
# schubert_all/
# dvorak_(c)contributors-kunstderfuge/
# (248, 128000)
# (248, 32)
# schubert_all/
# debussy_all/
# (360, 128000)
# (360, 32)
# schubert_all/
# faure_(c)contributors-kunstderfuge/
# (253, 128000)
# (253, 32)
# schubert_all/
# handel_all/
# (439, 128000)
# (439, 32)
# schubert_all/
# haydn_all/
# (631, 128000)
# (631, 32)
# schubert_all/
# mozart_all/
# (531, 128000)
# (531, 32)
# schubert_all/
# scarlatti_all/
# (738, 128000)
# (738, 32)
# schubert_all/
# schubert_all/
# (366, 128000)
# (366, 32)
# schubert_all/
# schumann_(c)contributors-kunstderfuge/
# (251, 128000)
# (251, 32)
# schubert_all/
# scriabin_(c)contributors-kunstderfuge/
# (268, 128000)
# (268, 32)
# schubert_all/
# shostakovich_(c)contributors-kunstderfuge/
# (283, 128000)
# (283, 32)
# schubert_all/
# soler_(c)contributors-kunstderfuge/
# (236, 128000)
# (236, 32)
# schumann_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (272, 128000)
# (272, 32)
# schumann_(c)contributors-kunstderfuge/
# bach_all/
# (1083, 128000)
# (1083, 32)
# schumann_(c)contributors-kunstderfuge/
# beethoven_all/
# (496, 128000)
# (496, 32)
# schumann_(c)contributors-kunstderfuge/
# brahms_all/
# (186, 128000)
# (186, 32)
# schumann_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (137, 128000)
# (137, 32)
# schumann_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (170, 128000)
# (170, 32)
# schumann_(c)contributors-kunstderfuge/
# chopin_all/
# (215, 128000)
# (215, 32)
# schumann_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (131, 128000)
# (131, 32)
# schumann_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (133, 128000)
# (133, 32)
# schumann_(c)contributors-kunstderfuge/
# debussy_all/
# (245, 128000)
# (245, 32)
# schumann_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (138, 128000)
# (138, 32)
# schumann_(c)contributors-kunstderfuge/
# handel_all/
# (324, 128000)
# (324, 32)
# schumann_(c)contributors-kunstderfuge/
# haydn_all/
# (516, 128000)
# (516, 32)
# schumann_(c)contributors-kunstderfuge/
# mozart_all/
# (416, 128000)
# (416, 32)
# schumann_(c)contributors-kunstderfuge/
# scarlatti_all/
# (623, 128000)
# (623, 32)
# schumann_(c)contributors-kunstderfuge/
# schubert_all/
# (251, 128000)
# (251, 32)
# schumann_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (136, 128000)
# (136, 32)
# schumann_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (153, 128000)
# (153, 32)
# schumann_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (168, 128000)
# (168, 32)
# schumann_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (121, 128000)
# (121, 32)
# scriabin_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (289, 128000)
# (289, 32)
# scriabin_(c)contributors-kunstderfuge/
# bach_all/
# (1100, 128000)
# (1100, 32)
# scriabin_(c)contributors-kunstderfuge/
# beethoven_all/
# (513, 128000)
# (513, 32)
# scriabin_(c)contributors-kunstderfuge/
# brahms_all/
# (203, 128000)
# (203, 32)
# scriabin_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (154, 128000)
# (154, 32)
# scriabin_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (187, 128000)
# (187, 32)
# scriabin_(c)contributors-kunstderfuge/
# chopin_all/
# (232, 128000)
# (232, 32)
# scriabin_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (148, 128000)
# (148, 32)
# scriabin_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (150, 128000)
# (150, 32)
# scriabin_(c)contributors-kunstderfuge/
# debussy_all/
# (262, 128000)
# (262, 32)
# scriabin_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (155, 128000)
# (155, 32)
# scriabin_(c)contributors-kunstderfuge/
# handel_all/
# (341, 128000)
# (341, 32)
# scriabin_(c)contributors-kunstderfuge/
# haydn_all/
# (533, 128000)
# (533, 32)
# scriabin_(c)contributors-kunstderfuge/
# mozart_all/
# (433, 128000)
# (433, 32)
# scriabin_(c)contributors-kunstderfuge/
# scarlatti_all/
# (640, 128000)
# (640, 32)
# scriabin_(c)contributors-kunstderfuge/
# schubert_all/
# (268, 128000)
# (268, 32)
# scriabin_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (153, 128000)
# (153, 32)
# scriabin_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (170, 128000)
# (170, 32)
# scriabin_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (185, 128000)
# (185, 32)
# scriabin_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (138, 128000)
# (138, 32)
# shostakovich_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (304, 128000)
# (304, 32)
# shostakovich_(c)contributors-kunstderfuge/
# bach_all/
# (1115, 128000)
# (1115, 32)
# shostakovich_(c)contributors-kunstderfuge/
# beethoven_all/
# (528, 128000)
# (528, 32)
# shostakovich_(c)contributors-kunstderfuge/
# brahms_all/
# (218, 128000)
# (218, 32)
# shostakovich_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (169, 128000)
# (169, 32)
# shostakovich_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (202, 128000)
# (202, 32)
# shostakovich_(c)contributors-kunstderfuge/
# chopin_all/
# (247, 128000)
# (247, 32)
# shostakovich_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (163, 128000)
# (163, 32)
# shostakovich_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (165, 128000)
# (165, 32)
# shostakovich_(c)contributors-kunstderfuge/
# debussy_all/
# (277, 128000)
# (277, 32)
# shostakovich_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (170, 128000)
# (170, 32)
# shostakovich_(c)contributors-kunstderfuge/
# handel_all/
# (356, 128000)
# (356, 32)
# shostakovich_(c)contributors-kunstderfuge/
# haydn_all/
# (548, 128000)
# (548, 32)
# shostakovich_(c)contributors-kunstderfuge/
# mozart_all/
# (448, 128000)
# (448, 32)
# shostakovich_(c)contributors-kunstderfuge/
# scarlatti_all/
# (655, 128000)
# (655, 32)
# shostakovich_(c)contributors-kunstderfuge/
# schubert_all/
# (283, 128000)
# (283, 32)
# shostakovich_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (168, 128000)
# (168, 32)
# shostakovich_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (185, 128000)
# (185, 32)
# shostakovich_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (200, 128000)
# (200, 32)
# shostakovich_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (153, 128000)
# (153, 32)
# soler_(c)contributors-kunstderfuge/
# alkan_(c)contributors-kunstderfuge/
# (257, 128000)
# (257, 32)
# soler_(c)contributors-kunstderfuge/
# bach_all/
# (1068, 128000)
# (1068, 32)
# soler_(c)contributors-kunstderfuge/
# beethoven_all/
# (481, 128000)
# (481, 32)
# soler_(c)contributors-kunstderfuge/
# brahms_all/
# (171, 128000)
# (171, 32)
# soler_(c)contributors-kunstderfuge/
# buxtehude_(c)contributors-kunstderfuge/
# (122, 128000)
# (122, 32)
# soler_(c)contributors-kunstderfuge/
# byrd_(c)contributors-kunstderfuge/
# (155, 128000)
# (155, 32)
# soler_(c)contributors-kunstderfuge/
# chopin_all/
# (200, 128000)
# (200, 32)
# soler_(c)contributors-kunstderfuge/
# dandrieu_(c)contributors-kunstderfuge/
# (116, 128000)
# (116, 32)
# soler_(c)contributors-kunstderfuge/
# dvorak_(c)contributors-kunstderfuge/
# (118, 128000)
# (118, 32)
# soler_(c)contributors-kunstderfuge/
# debussy_all/
# (230, 128000)
# (230, 32)
# soler_(c)contributors-kunstderfuge/
# faure_(c)contributors-kunstderfuge/
# (123, 128000)
# (123, 32)
# soler_(c)contributors-kunstderfuge/
# handel_all/
# (309, 128000)
# (309, 32)
# soler_(c)contributors-kunstderfuge/
# haydn_all/
# (501, 128000)
# (501, 32)
# soler_(c)contributors-kunstderfuge/
# mozart_all/
# (401, 128000)
# (401, 32)
# soler_(c)contributors-kunstderfuge/
# scarlatti_all/
# (608, 128000)
# (608, 32)
# soler_(c)contributors-kunstderfuge/
# schubert_all/
# (236, 128000)
# (236, 32)
# soler_(c)contributors-kunstderfuge/
# schumann_(c)contributors-kunstderfuge/
# (121, 128000)
# (121, 32)
# soler_(c)contributors-kunstderfuge/
# scriabin_(c)contributors-kunstderfuge/
# (138, 128000)
# (138, 32)
# soler_(c)contributors-kunstderfuge/
# shostakovich_(c)contributors-kunstderfuge/
# (153, 128000)
# (153, 32)
# soler_(c)contributors-kunstderfuge/
# soler_(c)contributors-kunstderfuge/
# (106, 128000)
# (106, 32)
# [[0.5  0.65 0.61 0.72 0.53 0.86 0.51 0.62 0.62 0.54 0.59 0.53 0.68 0.63
#   0.88 0.53 0.57 0.63 0.55 0.6 ]
#  [0.65 0.5  0.55 0.74 0.67 0.75 0.67 0.7  0.71 0.68 0.71 0.62 0.51 0.55
#   0.83 0.67 0.69 0.7  0.68 0.7 ]
#  [0.61 0.55 0.5  0.78 0.59 0.87 0.64 0.64 0.67 0.65 0.66 0.6  0.59 0.53
#   0.93 0.65 0.63 0.68 0.62 0.62]
#  [0.72 0.74 0.78 0.5  0.75 0.77 0.73 0.67 0.62 0.71 0.61 0.78 0.84 0.82
#   0.57 0.69 0.68 0.62 0.72 0.68]
#  [0.53 0.67 0.59 0.75 0.5  0.89 0.54 0.64 0.72 0.52 0.61 0.64 0.64 0.6
#   0.85 0.53 0.58 0.64 0.54 0.55]
#  [0.86 0.75 0.87 0.77 0.89 0.5  0.87 0.85 0.8  0.82 0.83 0.89 0.94 0.9
#   0.61 0.8  0.84 0.81 0.85 0.86]
#  [0.51 0.67 0.64 0.73 0.54 0.87 0.5  0.62 0.66 0.52 0.62 0.51 0.72 0.67
#   0.84 0.52 0.58 0.62 0.54 0.6 ]
#  [0.62 0.7  0.64 0.67 0.64 0.85 0.62 0.5  0.66 0.51 0.5  0.5  0.7  0.65
#   0.7  0.59 0.5  0.57 0.56 0.55]
#  [0.62 0.71 0.67 0.62 0.72 0.8  0.66 0.66 0.5  0.61 0.56 0.56 0.75 0.71
#   0.57 0.61 0.59 0.51 0.65 0.65]
#  [0.54 0.68 0.65 0.71 0.52 0.82 0.51 0.51 0.61 0.5  0.56 0.52 0.73 0.68
#   0.82 0.51 0.55 0.6  0.51 0.56]
#  [0.58 0.71 0.66 0.61 0.61 0.83 0.62 0.5  0.56 0.56 0.5  0.53 0.75 0.71
#   0.66 0.58 0.52 0.55 0.58 0.5 ]
#  [0.53 0.62 0.6  0.78 0.59 0.89 0.51 0.5  0.56 0.52 0.53 0.5  0.71 0.65
#   0.92 0.52 0.52 0.55 0.52 0.52]
#  [0.68 0.51 0.59 0.84 0.64 0.94 0.72 0.7  0.75 0.73 0.75 0.71 0.5  0.55
#   0.97 0.74 0.71 0.74 0.71 0.68]
#  [0.63 0.55 0.53 0.82 0.6  0.9  0.67 0.65 0.71 0.68 0.71 0.65 0.55 0.5
#   0.95 0.67 0.65 0.7  0.66 0.64]
#  [0.88 0.83 0.93 0.57 0.83 0.61 0.84 0.7  0.57 0.82 0.66 0.92 0.97 0.95
#   0.5  0.86 0.71 0.69 0.8  0.71]
#  [0.53 0.67 0.65 0.69 0.51 0.8  0.52 0.59 0.61 0.51 0.58 0.52 0.74 0.67
#   0.86 0.5  0.55 0.59 0.51 0.59]
#  [0.57 0.69 0.63 0.68 0.58 0.84 0.58 0.5  0.59 0.55 0.52 0.52 0.71 0.65
#   0.71 0.55 0.5  0.57 0.58 0.52]
#  [0.63 0.7  0.68 0.62 0.64 0.81 0.62 0.57 0.51 0.6  0.55 0.55 0.74 0.7
#   0.69 0.59 0.57 0.5  0.61 0.59]
#  [0.55 0.68 0.62 0.72 0.54 0.85 0.54 0.56 0.65 0.5  0.58 0.52 0.71 0.66
#   0.8  0.51 0.57 0.61 0.5  0.56]
#  [0.6  0.7  0.62 0.68 0.55 0.86 0.6  0.56 0.64 0.56 0.5  0.52 0.68 0.64
#   0.71 0.59 0.52 0.59 0.56 0.5 ]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ab88f467a97b> in <module>()
#      30 im = ax.imshow(data, cmap="Wistia")
#      31
# ---> 32 comps_names = [c[:-8] for c in csv_comps]
#      33
#      34 # We want to show all ticks...
#
# NameError: name 'csv_comps' is not defined
